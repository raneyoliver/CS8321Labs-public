# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

# %% [markdown]
# ## 1000 Runs

# %%
results_iter1 = pd.read_csv('iter1_results1000.csv')
results_iter1.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f10b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f10b4_level0_col0" class="col_heading level0 col0" >Num_Steps</th>
#       <th id="T_f10b4_level0_col1" class="col_heading level0 col1" >Median_Error</th>
#       <th id="T_f10b4_level0_col2" class="col_heading level0 col2" >Median_CEP</th>
#       <th id="T_f10b4_level0_col3" class="col_heading level0 col3" >Median_X</th>
#       <th id="T_f10b4_level0_col4" class="col_heading level0 col4" >Median_Y</th>
#       <th id="T_f10b4_level0_col5" class="col_heading level0 col5" >MAD_X</th>
#       <th id="T_f10b4_level0_col6" class="col_heading level0 col6" >MAD_Y</th>
#       <th id="T_f10b4_level0_col7" class="col_heading level0 col7" >Mean_X</th>
#       <th id="T_f10b4_level0_col8" class="col_heading level0 col8" >Mean_Y</th>
#       <th id="T_f10b4_level0_col9" class="col_heading level0 col9" >Std_X</th>
# ...

# %%
results_iter2 = pd.read_csv('iter2_results1000.csv')
results_iter2.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_67090">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67090_level0_col0" class="col_heading level0 col0" >Num_Steps</th>
#       <th id="T_67090_level0_col1" class="col_heading level0 col1" >Median_Error</th>
#       <th id="T_67090_level0_col2" class="col_heading level0 col2" >Median_CEP</th>
#       <th id="T_67090_level0_col3" class="col_heading level0 col3" >Median_X</th>
#       <th id="T_67090_level0_col4" class="col_heading level0 col4" >Median_Y</th>
#       <th id="T_67090_level0_col5" class="col_heading level0 col5" >MAD_X</th>
#       <th id="T_67090_level0_col6" class="col_heading level0 col6" >MAD_Y</th>
#       <th id="T_67090_level0_col7" class="col_heading level0 col7" >Mean_X</th>
#       <th id="T_67090_level0_col8" class="col_heading level0 col8" >Mean_Y</th>
#       <th id="T_67090_level0_col9" class="col_heading level0 col9" >Std_X</th>
# ...

# %%
results_iter3 = pd.read_csv('iter3_results1000.csv')
results_iter3.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_8d126">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d126_level0_col0" class="col_heading level0 col0" >Num_Steps</th>
#       <th id="T_8d126_level0_col1" class="col_heading level0 col1" >Median_Error</th>
#       <th id="T_8d126_level0_col2" class="col_heading level0 col2" >Median_CEP</th>
#       <th id="T_8d126_level0_col3" class="col_heading level0 col3" >Median_X</th>
#       <th id="T_8d126_level0_col4" class="col_heading level0 col4" >Median_Y</th>
#       <th id="T_8d126_level0_col5" class="col_heading level0 col5" >MAD_X</th>
#       <th id="T_8d126_level0_col6" class="col_heading level0 col6" >MAD_Y</th>
#       <th id="T_8d126_level0_col7" class="col_heading level0 col7" >Mean_X</th>
#       <th id="T_8d126_level0_col8" class="col_heading level0 col8" >Mean_Y</th>
#       <th id="T_8d126_level0_col9" class="col_heading level0 col9" >Std_X</th>
# ...

# %%
# Plot Results
plt.scatter(350,350,color='red', label='True Target Location', marker='x',s=200)

mean_num_steps = results_iter1['Num_Steps'].mean()
mean_median_error = results_iter1['Median_Error'].mean()
mean_median_cep = results_iter1['Median_CEP'].mean()
mean_median_x = results_iter1['Median_X'].mean()
mean_median_y = results_iter1['Median_Y'].mean()
mean_mad_x = results_iter1['MAD_X'].mean()
mean_mad_y = results_iter1['MAD_Y'].mean()

# Plot circle using MAD deviations of x & y values
radius = mean_median_cep
median_cep_legend1 = f'Median CEP Iteration 1 \nMean Error: ({np.round(mean_median_error,1)})'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='blue', facecolor='none', linestyle='-', linewidth=2, label=median_cep_legend1)
plt.gca().add_patch(circle_median)

mean_num_steps = results_iter2['Num_Steps'].mean()
mean_median_error = results_iter2['Median_Error'].mean()
mean_median_cep = results_iter2['Median_CEP'].mean()
mean_median_x = results_iter2['Median_X'].mean()
mean_median_y = results_iter2['Median_Y'].mean()
mean_mad_x = results_iter2['MAD_X'].mean()
mean_mad_y = results_iter2['MAD_Y'].mean()

# Plot circle using MAD deviations of x & y values
radius = mean_median_cep
median_cep_legend2 = f'Median CEP Iteration 2 \nMean Error: ({np.round(mean_median_error,1)})'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='red', facecolor='none', linestyle='-', linewidth=2, label=median_cep_legend2)
plt.gca().add_patch(circle_median)

mean_num_steps = results_iter3['Num_Steps'].mean()
mean_median_error = results_iter3['Median_Error'].mean()
mean_median_cep = results_iter3['Median_CEP'].mean()
mean_median_x = results_iter3['Median_X'].mean()
mean_median_y = results_iter3['Median_Y'].mean()
mean_mad_x = results_iter3['MAD_X'].mean()
mean_mad_y = results_iter3['MAD_Y'].mean()

# Plot circle using MAD deviations of x & y values
radius = mean_median_cep
median_cep_legend3 = f'Median CEP Iteration 3 \nMean Error: ({np.round(mean_median_error,1)})'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='black', facecolor='none', linestyle='-', linewidth=2, label=median_cep_legend3)
plt.gca().add_patch(circle_median)



plt.xlabel('X')
plt.ylabel('Y')
plt.title('Median CEP by Iteration')
plt.legend(
    loc='lower center', 
    bbox_to_anchor=(0.5, -.25),
    ncol=4, 
)
plt.grid(True)
plt.axis('equal')  # Equal aspect ratio
plt.show()

# %% [markdown]
# ## 10000 Runs

# %%
results_iter1 = pd.read_csv('iter1_results10000.csv')
results_iter1.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_0e758">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e758_level0_col0" class="col_heading level0 col0" >Num_Steps</th>
#       <th id="T_0e758_level0_col1" class="col_heading level0 col1" >Median_Error</th>
#       <th id="T_0e758_level0_col2" class="col_heading level0 col2" >Median_CEP</th>
#       <th id="T_0e758_level0_col3" class="col_heading level0 col3" >Median_X</th>
#       <th id="T_0e758_level0_col4" class="col_heading level0 col4" >Median_Y</th>
#       <th id="T_0e758_level0_col5" class="col_heading level0 col5" >MAD_X</th>
#       <th id="T_0e758_level0_col6" class="col_heading level0 col6" >MAD_Y</th>
#       <th id="T_0e758_level0_col7" class="col_heading level0 col7" >Mean_X</th>
#       <th id="T_0e758_level0_col8" class="col_heading level0 col8" >Mean_Y</th>
#       <th id="T_0e758_level0_col9" class="col_heading level0 col9" >Std_X</th>
# ...

# %%
results_iter2 = pd.read_csv('iter2_results10000.csv')
results_iter2.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_7bf98">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7bf98_level0_col0" class="col_heading level0 col0" >Num_Steps</th>
#       <th id="T_7bf98_level0_col1" class="col_heading level0 col1" >Median_Error</th>
#       <th id="T_7bf98_level0_col2" class="col_heading level0 col2" >Median_CEP</th>
#       <th id="T_7bf98_level0_col3" class="col_heading level0 col3" >Median_X</th>
#       <th id="T_7bf98_level0_col4" class="col_heading level0 col4" >Median_Y</th>
#       <th id="T_7bf98_level0_col5" class="col_heading level0 col5" >MAD_X</th>
#       <th id="T_7bf98_level0_col6" class="col_heading level0 col6" >MAD_Y</th>
#       <th id="T_7bf98_level0_col7" class="col_heading level0 col7" >Mean_X</th>
#       <th id="T_7bf98_level0_col8" class="col_heading level0 col8" >Mean_Y</th>
#       <th id="T_7bf98_level0_col9" class="col_heading level0 col9" >Std_X</th>
# ...

# %%
results_iter3 = pd.read_csv('iter3_results10000.csv')
results_iter3.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_8d126">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d126_level0_col0" class="col_heading level0 col0" >Num_Steps</th>
#       <th id="T_8d126_level0_col1" class="col_heading level0 col1" >Median_Error</th>
#       <th id="T_8d126_level0_col2" class="col_heading level0 col2" >Median_CEP</th>
#       <th id="T_8d126_level0_col3" class="col_heading level0 col3" >Median_X</th>
#       <th id="T_8d126_level0_col4" class="col_heading level0 col4" >Median_Y</th>
#       <th id="T_8d126_level0_col5" class="col_heading level0 col5" >MAD_X</th>
#       <th id="T_8d126_level0_col6" class="col_heading level0 col6" >MAD_Y</th>
#       <th id="T_8d126_level0_col7" class="col_heading level0 col7" >Mean_X</th>
#       <th id="T_8d126_level0_col8" class="col_heading level0 col8" >Mean_Y</th>
#       <th id="T_8d126_level0_col9" class="col_heading level0 col9" >Std_X</th>
# ...

# %%
# Plot Results
plt.scatter(350,350,color='red', label='True Target Location', marker='x',s=200)

mean_num_steps = results_iter1['Num_Steps'].mean()
mean_median_error = results_iter1['Median_Error'].mean()
mean_median_cep = results_iter1['Median_CEP'].mean()
mean_median_x = results_iter1['Median_X'].mean()
mean_median_y = results_iter1['Median_Y'].mean()
mean_mad_x = results_iter1['MAD_X'].mean()
mean_mad_y = results_iter1['MAD_Y'].mean()

# Plot circle using MAD deviations of x & y values
radius = mean_median_cep
median_cep_legend1 = f'Median CEP Iteration 1 \nMean Error: ({np.round(mean_median_error,1)})'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='blue', facecolor='none', linestyle='-', linewidth=2, label=median_cep_legend1)
plt.gca().add_patch(circle_median)

mean_num_steps = results_iter2['Num_Steps'].mean()
mean_median_error = results_iter2['Median_Error'].mean()
mean_median_cep = results_iter2['Median_CEP'].mean()
mean_median_x = results_iter2['Median_X'].mean()
mean_median_y = results_iter2['Median_Y'].mean()
mean_mad_x = results_iter2['MAD_X'].mean()
mean_mad_y = results_iter2['MAD_Y'].mean()

# Plot circle using MAD deviations of x & y values
radius = mean_median_cep
median_cep_legend2 = f'Median CEP Iteration 2 \nMean Error: ({np.round(mean_median_error,1)})'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='red', facecolor='none', linestyle='-', linewidth=2, label=median_cep_legend2)
plt.gca().add_patch(circle_median)

mean_num_steps = results_iter3['Num_Steps'].mean()
mean_median_error = results_iter3['Median_Error'].mean()
mean_median_cep = results_iter3['Median_CEP'].mean()
mean_median_x = results_iter3['Median_X'].mean()
mean_median_y = results_iter3['Median_Y'].mean()
mean_mad_x = results_iter3['MAD_X'].mean()
mean_mad_y = results_iter3['MAD_Y'].mean()

# Plot circle using MAD deviations of x & y values
radius = mean_median_cep
median_cep_legend3 = f'Median CEP Iteration 3 \nMean Error: ({np.round(mean_median_error,1)})'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='black', facecolor='none', linestyle='-', linewidth=2, label=median_cep_legend3)
plt.gca().add_patch(circle_median)



plt.xlabel('X')
plt.ylabel('Y')
plt.title('Median CEP by Iteration')
plt.legend(
    loc='lower center', 
    bbox_to_anchor=(0.5, -.25),
    ncol=4, 
)
plt.grid(True)
plt.axis('equal')  # Equal aspect ratio
plt.show()
