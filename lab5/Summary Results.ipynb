# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

# %% [markdown]
# ## 1000 Runs

# %%
results_iter1 = pd.read_csv('iter1_results1000.csv')
results_iter1.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_25cb1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25cb1_level0_col0" class="col_heading level0 col0" >Num_Steps</th>
#       <th id="T_25cb1_level0_col1" class="col_heading level0 col1" >Median_Error</th>
#       <th id="T_25cb1_level0_col2" class="col_heading level0 col2" >Median_CEP</th>
#       <th id="T_25cb1_level0_col3" class="col_heading level0 col3" >Median_X</th>
#       <th id="T_25cb1_level0_col4" class="col_heading level0 col4" >Median_Y</th>
#       <th id="T_25cb1_level0_col5" class="col_heading level0 col5" >MAD_X</th>
#       <th id="T_25cb1_level0_col6" class="col_heading level0 col6" >MAD_Y</th>
#       <th id="T_25cb1_level0_col7" class="col_heading level0 col7" >Mean_X</th>
#       <th id="T_25cb1_level0_col8" class="col_heading level0 col8" >Mean_Y</th>
#       <th id="T_25cb1_level0_col9" class="col_heading level0 col9" >Std_X</th>
#       <th id="T_25cb1_level0_col10" class="col_heading level0 col10" >Std_Y</th>
#       <th id="T_25cb1_level0_col11" class="col_heading level0 col11" >Distance_Moved</th>
#       <th id="T_25cb1_level0_col12" class="col_heading level0 col12" >TotalReward</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25cb1_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_25cb1_row0_col0" class="data row0 col0" >1000.00</td>
#       <td id="T_25cb1_row0_col1" class="data row0 col1" >1000.00</td>
#       <td id="T_25cb1_row0_col2" class="data row0 col2" >1000.00</td>
#       <td id="T_25cb1_row0_col3" class="data row0 col3" >1000.00</td>
#       <td id="T_25cb1_row0_col4" class="data row0 col4" >1000.00</td>
#       <td id="T_25cb1_row0_col5" class="data row0 col5" >1000.00</td>
#       <td id="T_25cb1_row0_col6" class="data row0 col6" >1000.00</td>
#       <td id="T_25cb1_row0_col7" class="data row0 col7" >1000.00</td>
#       <td id="T_25cb1_row0_col8" class="data row0 col8" >1000.00</td>
#       <td id="T_25cb1_row0_col9" class="data row0 col9" >1000.00</td>
#       <td id="T_25cb1_row0_col10" class="data row0 col10" >1000.00</td>
#       <td id="T_25cb1_row0_col11" class="data row0 col11" >1000.00</td>
#       <td id="T_25cb1_row0_col12" class="data row0 col12" >1000.00</td>
#     </tr>
#     <tr>
#       <th id="T_25cb1_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_25cb1_row1_col0" class="data row1 col0" >121.39</td>
#       <td id="T_25cb1_row1_col1" class="data row1 col1" >13.33</td>
#       <td id="T_25cb1_row1_col2" class="data row1 col2" >1.83</td>
#       <td id="T_25cb1_row1_col3" class="data row1 col3" >350.72</td>
#       <td id="T_25cb1_row1_col4" class="data row1 col4" >349.70</td>
#       <td id="T_25cb1_row1_col5" class="data row1 col5" >1.13</td>
#       <td id="T_25cb1_row1_col6" class="data row1 col6" >1.35</td>
#       <td id="T_25cb1_row1_col7" class="data row1 col7" >350.70</td>
#       <td id="T_25cb1_row1_col8" class="data row1 col8" >347.27</td>
#       <td id="T_25cb1_row1_col9" class="data row1 col9" >49.11</td>
#       <td id="T_25cb1_row1_col10" class="data row1 col10" >39.60</td>
#       <td id="T_25cb1_row1_col11" class="data row1 col11" >11006.56</td>
#       <td id="T_25cb1_row1_col12" class="data row1 col12" >120.47</td>
#     </tr>
#     <tr>
#       <th id="T_25cb1_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_25cb1_row2_col0" class="data row2 col0" >122.63</td>
#       <td id="T_25cb1_row2_col1" class="data row2 col1" >24.92</td>
#       <td id="T_25cb1_row2_col2" class="data row2 col2" >10.60</td>
#       <td id="T_25cb1_row2_col3" class="data row2 col3" >19.97</td>
#       <td id="T_25cb1_row2_col4" class="data row2 col4" >15.50</td>
#       <td id="T_25cb1_row2_col5" class="data row2 col5" >5.49</td>
#       <td id="T_25cb1_row2_col6" class="data row2 col6" >9.09</td>
#       <td id="T_25cb1_row2_col7" class="data row2 col7" >116.40</td>
#       <td id="T_25cb1_row2_col8" class="data row2 col8" >96.30</td>
#       <td id="T_25cb1_row2_col9" class="data row2 col9" >598.59</td>
#       <td id="T_25cb1_row2_col10" class="data row2 col10" >493.92</td>
#       <td id="T_25cb1_row2_col11" class="data row2 col11" >11826.54</td>
#       <td id="T_25cb1_row2_col12" class="data row2 col12" >251.07</td>
#     </tr>
#     <tr>
#       <th id="T_25cb1_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_25cb1_row3_col0" class="data row3 col0" >1.00</td>
#       <td id="T_25cb1_row3_col1" class="data row3 col1" >0.01</td>
#       <td id="T_25cb1_row3_col2" class="data row3 col2" >0.02</td>
#       <td id="T_25cb1_row3_col3" class="data row3 col3" >234.88</td>
#       <td id="T_25cb1_row3_col4" class="data row3 col4" >197.13</td>
#       <td id="T_25cb1_row3_col5" class="data row3 col5" >0.01</td>
#       <td id="T_25cb1_row3_col6" class="data row3 col6" >0.02</td>
#       <td id="T_25cb1_row3_col7" class="data row3 col7" >-1578.30</td>
#       <td id="T_25cb1_row3_col8" class="data row3 col8" >-2395.53</td>
#       <td id="T_25cb1_row3_col9" class="data row3 col9" >0.09</td>
#       <td id="T_25cb1_row3_col10" class="data row3 col10" >0.04</td>
#       <td id="T_25cb1_row3_col11" class="data row3 col11" >3287.88</td>
#       <td id="T_25cb1_row3_col12" class="data row3 col12" >-1448.00</td>
#     </tr>
#     <tr>
#       <th id="T_25cb1_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_25cb1_row4_col0" class="data row4 col0" >48.75</td>
#       <td id="T_25cb1_row4_col1" class="data row4 col1" >3.86</td>
#       <td id="T_25cb1_row4_col2" class="data row4 col2" >0.94</td>
#       <td id="T_25cb1_row4_col3" class="data row4 col3" >344.28</td>
#       <td id="T_25cb1_row4_col4" class="data row4 col4" >343.70</td>
#       <td id="T_25cb1_row4_col5" class="data row4 col5" >0.52</td>
#       <td id="T_25cb1_row4_col6" class="data row4 col6" >0.59</td>
#       <td id="T_25cb1_row4_col7" class="data row4 col7" >343.44</td>
#       <td id="T_25cb1_row4_col8" class="data row4 col8" >343.23</td>
#       <td id="T_25cb1_row4_col9" class="data row4 col9" >2.54</td>
#       <td id="T_25cb1_row4_col10" class="data row4 col10" >2.50</td>
#       <td id="T_25cb1_row4_col11" class="data row4 col11" >7638.03</td>
#       <td id="T_25cb1_row4_col12" class="data row4 col12" >14.00</td>
#     </tr>
#     <tr>
#       <th id="T_25cb1_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_25cb1_row5_col0" class="data row5 col0" >89.00</td>
#       <td id="T_25cb1_row5_col1" class="data row5 col1" >7.89</td>
#       <td id="T_25cb1_row5_col2" class="data row5 col2" >1.36</td>
#       <td id="T_25cb1_row5_col3" class="data row5 col3" >349.87</td>
#       <td id="T_25cb1_row5_col4" class="data row5 col4" >350.13</td>
#       <td id="T_25cb1_row5_col5" class="data row5 col5" >0.80</td>
#       <td id="T_25cb1_row5_col6" class="data row5 col6" >0.90</td>
#       <td id="T_25cb1_row5_col7" class="data row5 col7" >349.72</td>
#       <td id="T_25cb1_row5_col8" class="data row5 col8" >349.92</td>
#       <td id="T_25cb1_row5_col9" class="data row5 col9" >5.33</td>
#       <td id="T_25cb1_row5_col10" class="data row5 col10" >5.19</td>
#       <td id="T_25cb1_row5_col11" class="data row5 col11" >8924.95</td>
#       <td id="T_25cb1_row5_col12" class="data row5 col12" >78.00</td>
#     </tr>
#     <tr>
#       <th id="T_25cb1_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_25cb1_row6_col0" class="data row6 col0" >150.75</td>
#       <td id="T_25cb1_row6_col1" class="data row6 col1" >14.54</td>
#       <td id="T_25cb1_row6_col2" class="data row6 col2" >1.70</td>
#       <td id="T_25cb1_row6_col3" class="data row6 col3" >355.49</td>
#       <td id="T_25cb1_row6_col4" class="data row6 col4" >356.66</td>
#       <td id="T_25cb1_row6_col5" class="data row6 col5" >1.14</td>
#       <td id="T_25cb1_row6_col6" class="data row6 col6" >1.24</td>
#       <td id="T_25cb1_row6_col7" class="data row6 col7" >355.76</td>
#       <td id="T_25cb1_row6_col8" class="data row6 col8" >357.39</td>
#       <td id="T_25cb1_row6_col9" class="data row6 col9" >12.57</td>
#       <td id="T_25cb1_row6_col10" class="data row

# %%
results_iter2 = pd.read_csv('iter2_results1000.csv')
results_iter2.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_271af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_271af_level0_col0" class="col_heading level0 col0" >Num_Steps</th>
#       <th id="T_271af_level0_col1" class="col_heading level0 col1" >Median_Error</th>
#       <th id="T_271af_level0_col2" class="col_heading level0 col2" >Median_CEP</th>
#       <th id="T_271af_level0_col3" class="col_heading level0 col3" >Median_X</th>
#       <th id="T_271af_level0_col4" class="col_heading level0 col4" >Median_Y</th>
#       <th id="T_271af_level0_col5" class="col_heading level0 col5" >MAD_X</th>
#       <th id="T_271af_level0_col6" class="col_heading level0 col6" >MAD_Y</th>
#       <th id="T_271af_level0_col7" class="col_heading level0 col7" >Mean_X</th>
#       <th id="T_271af_level0_col8" class="col_heading level0 col8" >Mean_Y</th>
#       <th id="T_271af_level0_col9" class="col_heading level0 col9" >Std_X</th>
#       <th id="T_271af_level0_col10" class="col_heading level0 col10" >Std_Y</th>
#       <th id="T_271af_level0_col11" class="col_heading level0 col11" >Distance_Moved</th>
#       <th id="T_271af_level0_col12" class="col_heading level0 col12" >TotalReward</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_271af_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_271af_row0_col0" class="data row0 col0" >1000.00</td>
#       <td id="T_271af_row0_col1" class="data row0 col1" >1000.00</td>
#       <td id="T_271af_row0_col2" class="data row0 col2" >1000.00</td>
#       <td id="T_271af_row0_col3" class="data row0 col3" >1000.00</td>
#       <td id="T_271af_row0_col4" class="data row0 col4" >1000.00</td>
#       <td id="T_271af_row0_col5" class="data row0 col5" >1000.00</td>
#       <td id="T_271af_row0_col6" class="data row0 col6" >1000.00</td>
#       <td id="T_271af_row0_col7" class="data row0 col7" >1000.00</td>
#       <td id="T_271af_row0_col8" class="data row0 col8" >1000.00</td>
#       <td id="T_271af_row0_col9" class="data row0 col9" >1000.00</td>
#       <td id="T_271af_row0_col10" class="data row0 col10" >1000.00</td>
#       <td id="T_271af_row0_col11" class="data row0 col11" >1000.00</td>
#       <td id="T_271af_row0_col12" class="data row0 col12" >1000.00</td>
#     </tr>
#     <tr>
#       <th id="T_271af_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_271af_row1_col0" class="data row1 col0" >160.18</td>
#       <td id="T_271af_row1_col1" class="data row1 col1" >18.70</td>
#       <td id="T_271af_row1_col2" class="data row1 col2" >7.43</td>
#       <td id="T_271af_row1_col3" class="data row1 col3" >351.32</td>
#       <td id="T_271af_row1_col4" class="data row1 col4" >346.33</td>
#       <td id="T_271af_row1_col5" class="data row1 col5" >4.70</td>
#       <td id="T_271af_row1_col6" class="data row1 col6" >4.85</td>
#       <td id="T_271af_row1_col7" class="data row1 col7" >366.09</td>
#       <td id="T_271af_row1_col8" class="data row1 col8" >360.57</td>
#       <td id="T_271af_row1_col9" class="data row1 col9" >128.44</td>
#       <td id="T_271af_row1_col10" class="data row1 col10" >107.37</td>
#       <td id="T_271af_row1_col11" class="data row1 col11" >11926.39</td>
#       <td id="T_271af_row1_col12" class="data row1 col12" >-2.09</td>
#     </tr>
#     <tr>
#       <th id="T_271af_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_271af_row2_col0" class="data row2 col0" >200.11</td>
#       <td id="T_271af_row2_col1" class="data row2 col1" >61.05</td>
#       <td id="T_271af_row2_col2" class="data row2 col2" >64.64</td>
#       <td id="T_271af_row2_col3" class="data row2 col3" >45.13</td>
#       <td id="T_271af_row2_col4" class="data row2 col4" >71.58</td>
#       <td id="T_271af_row2_col5" class="data row2 col5" >34.88</td>
#       <td id="T_271af_row2_col6" class="data row2 col6" >54.51</td>
#       <td id="T_271af_row2_col7" class="data row2 col7" >513.43</td>
#       <td id="T_271af_row2_col8" class="data row2 col8" >384.75</td>
#       <td id="T_271af_row2_col9" class="data row2 col9" >2654.45</td>
#       <td id="T_271af_row2_col10" class="data row2 col10" >2000.83</td>
#       <td id="T_271af_row2_col11" class="data row2 col11" >14857.42</td>
#       <td id="T_271af_row2_col12" class="data row2 col12" >98.27</td>
#     </tr>
#     <tr>
#       <th id="T_271af_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_271af_row3_col0" class="data row3 col0" >1.00</td>
#       <td id="T_271af_row3_col1" class="data row3 col1" >0.01</td>
#       <td id="T_271af_row3_col2" class="data row3 col2" >0.08</td>
#       <td id="T_271af_row3_col3" class="data row3 col3" >-156.49</td>
#       <td id="T_271af_row3_col4" class="data row3 col4" >-1569.94</td>
#       <td id="T_271af_row3_col5" class="data row3 col5" >0.03</td>
#       <td id="T_271af_row3_col6" class="data row3 col6" >0.03</td>
#       <td id="T_271af_row3_col7" class="data row3 col7" >-725.15</td>
#       <td id="T_271af_row3_col8" class="data row3 col8" >-1525.59</td>
#       <td id="T_271af_row3_col9" class="data row3 col9" >0.22</td>
#       <td id="T_271af_row3_col10" class="data row3 col10" >0.18</td>
#       <td id="T_271af_row3_col11" class="data row3 col11" >3138.93</td>
#       <td id="T_271af_row3_col12" class="data row3 col12" >-882.00</td>
#     </tr>
#     <tr>
#       <th id="T_271af_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_271af_row4_col0" class="data row4 col0" >48.75</td>
#       <td id="T_271af_row4_col1" class="data row4 col1" >3.88</td>
#       <td id="T_271af_row4_col2" class="data row4 col2" >0.99</td>
#       <td id="T_271af_row4_col3" class="data row4 col3" >343.88</td>
#       <td id="T_271af_row4_col4" class="data row4 col4" >343.80</td>
#       <td id="T_271af_row4_col5" class="data row4 col5" >0.53</td>
#       <td id="T_271af_row4_col6" class="data row4 col6" >0.56</td>
#       <td id="T_271af_row4_col7" class="data row4 col7" >342.86</td>
#       <td id="T_271af_row4_col8" class="data row4 col8" >343.29</td>
#       <td id="T_271af_row4_col9" class="data row4 col9" >2.73</td>
#       <td id="T_271af_row4_col10" class="data row4 col10" >2.52</td>
#       <td id="T_271af_row4_col11" class="data row4 col11" >6790.25</td>
#       <td id="T_271af_row4_col12" class="data row4 col12" >-28.00</td>
#     </tr>
#     <tr>
#       <th id="T_271af_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_271af_row5_col0" class="data row5 col0" >92.50</td>
#       <td id="T_271af_row5_col1" class="data row5 col1" >8.74</td>
#       <td id="T_271af_row5_col2" class="data row5 col2" >1.41</td>
#       <td id="T_271af_row5_col3" class="data row5 col3" >349.88</td>
#       <td id="T_271af_row5_col4" class="data row5 col4" >350.00</td>
#       <td id="T_271af_row5_col5" class="data row5 col5" >0.88</td>
#       <td id="T_271af_row5_col6" class="data row5 col6" >0.89</td>
#       <td id="T_271af_row5_col7" class="data row5 col7" >350.05</td>
#       <td id="T_271af_row5_col8" class="data row5 col8" >350.18</td>
#       <td id="T_271af_row5_col9" class="data row5 col9" >5.38</td>
#       <td id="T_271af_row5_col10" class="data row5 col10" >5.16</td>
#       <td id="T_271af_row5_col11" class="data row5 col11" >8094.91</td>
#       <td id="T_271af_row5_col12" class="data row5 col12" >14.00</td>
#     </tr>
#     <tr>
#       <th id="T_271af_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_271af_row6_col0" class="data row6 col0" >174.25</td>
#       <td id="T_271af_row6_col1" class="data row6 col1" >17.80</td>
#       <td id="T_271af_row6_col2" class="data row6 col2" >1.72</td>
#       <td id="T_271af_row6_col3" class="data row6 col3" >356.28</td>
#       <td id="T_271af_row6_col4" class="data row6 col4" >356.51</td>
#       <td id="T_271af_row6_col5" class="data row6 col5" >1.23</td>
#       <td id="T_271af_row6_col6" class="data row6 col6" >1.26</td>
#       <td id="T_271af_row6_col7" class="data row6 col7" >357.04</td>
#       <td id="T_271af_row6_col8" class="data row6 col8" >357.46</td>
#       <td id="T_271af_row6_col9" class="data row6 col9" >13.96</td>
#       <td id="T_271af_row6_col10" class="d

# %%
results_iter3 = pd.read_csv('iter3_1_results1000.csv')
results_iter3.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f54be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f54be_level0_col0" class="col_heading level0 col0" >Num_Steps</th>
#       <th id="T_f54be_level0_col1" class="col_heading level0 col1" >Median_Error</th>
#       <th id="T_f54be_level0_col2" class="col_heading level0 col2" >Median_CEP</th>
#       <th id="T_f54be_level0_col3" class="col_heading level0 col3" >Median_X</th>
#       <th id="T_f54be_level0_col4" class="col_heading level0 col4" >Median_Y</th>
#       <th id="T_f54be_level0_col5" class="col_heading level0 col5" >MAD_X</th>
#       <th id="T_f54be_level0_col6" class="col_heading level0 col6" >MAD_Y</th>
#       <th id="T_f54be_level0_col7" class="col_heading level0 col7" >Mean_X</th>
#       <th id="T_f54be_level0_col8" class="col_heading level0 col8" >Mean_Y</th>
#       <th id="T_f54be_level0_col9" class="col_heading level0 col9" >Std_X</th>
#       <th id="T_f54be_level0_col10" class="col_heading level0 col10" >Std_Y</th>
#       <th id="T_f54be_level0_col11" class="col_heading level0 col11" >Distance_Moved</th>
#       <th id="T_f54be_level0_col12" class="col_heading level0 col12" >TotalReward</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f54be_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_f54be_row0_col0" class="data row0 col0" >1000.00</td>
#       <td id="T_f54be_row0_col1" class="data row0 col1" >1000.00</td>
#       <td id="T_f54be_row0_col2" class="data row0 col2" >1000.00</td>
#       <td id="T_f54be_row0_col3" class="data row0 col3" >1000.00</td>
#       <td id="T_f54be_row0_col4" class="data row0 col4" >1000.00</td>
#       <td id="T_f54be_row0_col5" class="data row0 col5" >1000.00</td>
#       <td id="T_f54be_row0_col6" class="data row0 col6" >1000.00</td>
#       <td id="T_f54be_row0_col7" class="data row0 col7" >1000.00</td>
#       <td id="T_f54be_row0_col8" class="data row0 col8" >1000.00</td>
#       <td id="T_f54be_row0_col9" class="data row0 col9" >1000.00</td>
#       <td id="T_f54be_row0_col10" class="data row0 col10" >1000.00</td>
#       <td id="T_f54be_row0_col11" class="data row0 col11" >1000.00</td>
#       <td id="T_f54be_row0_col12" class="data row0 col12" >1000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f54be_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_f54be_row1_col0" class="data row1 col0" >293.45</td>
#       <td id="T_f54be_row1_col1" class="data row1 col1" >26.96</td>
#       <td id="T_f54be_row1_col2" class="data row1 col2" >19.64</td>
#       <td id="T_f54be_row1_col3" class="data row1 col3" >352.28</td>
#       <td id="T_f54be_row1_col4" class="data row1 col4" >361.70</td>
#       <td id="T_f54be_row1_col5" class="data row1 col5" >10.11</td>
#       <td id="T_f54be_row1_col6" class="data row1 col6" >14.92</td>
#       <td id="T_f54be_row1_col7" class="data row1 col7" >328.91</td>
#       <td id="T_f54be_row1_col8" class="data row1 col8" >294.92</td>
#       <td id="T_f54be_row1_col9" class="data row1 col9" >185.71</td>
#       <td id="T_f54be_row1_col10" class="data row1 col10" >536.65</td>
#       <td id="T_f54be_row1_col11" class="data row1 col11" >8159.02</td>
#       <td id="T_f54be_row1_col12" class="data row1 col12" >1173.79</td>
#     </tr>
#     <tr>
#       <th id="T_f54be_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_f54be_row2_col0" class="data row2 col0" >324.23</td>
#       <td id="T_f54be_row2_col1" class="data row2 col1" >39.86</td>
#       <td id="T_f54be_row2_col2" class="data row2 col2" >94.38</td>
#       <td id="T_f54be_row2_col3" class="data row2 col3" >33.96</td>
#       <td id="T_f54be_row2_col4" class="data row2 col4" >225.08</td>
#       <td id="T_f54be_row2_col5" class="data row2 col5" >34.58</td>
#       <td id="T_f54be_row2_col6" class="data row2 col6" >88.16</td>
#       <td id="T_f54be_row2_col7" class="data row2 col7" >552.63</td>
#       <td id="T_f54be_row2_col8" class="data row2 col8" >2054.85</td>
#       <td id="T_f54be_row2_col9" class="data row2 col9" >2867.98</td>
#       <td id="T_f54be_row2_col10" class="data row2 col10" >10795.40</td>
#       <td id="T_f54be_row2_col11" class="data row2 col11" >2165.73</td>
#       <td id="T_f54be_row2_col12" class="data row2 col12" >1296.94</td>
#     </tr>
#     <tr>
#       <th id="T_f54be_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_f54be_row3_col0" class="data row3 col0" >1.00</td>
#       <td id="T_f54be_row3_col1" class="data row3 col1" >0.02</td>
#       <td id="T_f54be_row3_col2" class="data row3 col2" >0.04</td>
#       <td id="T_f54be_row3_col3" class="data row3 col3" >-0.77</td>
#       <td id="T_f54be_row3_col4" class="data row3 col4" >-590.96</td>
#       <td id="T_f54be_row3_col5" class="data row3 col5" >0.02</td>
#       <td id="T_f54be_row3_col6" class="data row3 col6" >0.03</td>
#       <td id="T_f54be_row3_col7" class="data row3 col7" >-16586.12</td>
#       <td id="T_f54be_row3_col8" class="data row3 col8" >-63816.39</td>
#       <td id="T_f54be_row3_col9" class="data row3 col9" >0.09</td>
#       <td id="T_f54be_row3_col10" class="data row3 col10" >0.17</td>
#       <td id="T_f54be_row3_col11" class="data row3 col11" >3058.68</td>
#       <td id="T_f54be_row3_col12" class="data row3 col12" >4.00</td>
#     </tr>
#     <tr>
#       <th id="T_f54be_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_f54be_row4_col0" class="data row4 col0" >67.00</td>
#       <td id="T_f54be_row4_col1" class="data row4 col1" >6.27</td>
#       <td id="T_f54be_row4_col2" class="data row4 col2" >1.05</td>
#       <td id="T_f54be_row4_col3" class="data row4 col3" >341.44</td>
#       <td id="T_f54be_row4_col4" class="data row4 col4" >343.68</td>
#       <td id="T_f54be_row4_col5" class="data row4 col5" >0.68</td>
#       <td id="T_f54be_row4_col6" class="data row4 col6" >0.51</td>
#       <td id="T_f54be_row4_col7" class="data row4 col7" >339.30</td>
#       <td id="T_f54be_row4_col8" class="data row4 col8" >342.22</td>
#       <td id="T_f54be_row4_col9" class="data row4 col9" >2.97</td>
#       <td id="T_f54be_row4_col10" class="data row4 col10" >2.87</td>
#       <td id="T_f54be_row4_col11" class="data row4 col11" >6883.85</td>
#       <td id="T_f54be_row4_col12" class="data row4 col12" >268.00</td>
#     </tr>
#     <tr>
#       <th id="T_f54be_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_f54be_row5_col0" class="data row5 col0" >146.50</td>
#       <td id="T_f54be_row5_col1" class="data row5 col1" >14.77</td>
#       <td id="T_f54be_row5_col2" class="data row5 col2" >1.47</td>
#       <td id="T_f54be_row5_col3" class="data row5 col3" >351.09</td>
#       <td id="T_f54be_row5_col4" class="data row5 col4" >351.25</td>
#       <td id="T_f54be_row5_col5" class="data row5 col5" >1.02</td>
#       <td id="T_f54be_row5_col6" class="data row5 col6" >0.87</td>
#       <td id="T_f54be_row5_col7" class="data row5 col7" >351.07</td>
#       <td id="T_f54be_row5_col8" class="data row5 col8" >351.09</td>
#       <td id="T_f54be_row5_col9" class="data row5 col9" >7.31</td>
#       <td id="T_f54be_row5_col10" class="data row5 col10" >7.19</td>
#       <td id="T_f54be_row5_col11" class="data row5 col11" >8077.19</td>
#       <td id="T_f54be_row5_col12" class="data row5 col12" >586.00</td>
#     </tr>
#     <tr>
#       <th id="T_f54be_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_f54be_row6_col0" class="data row6 col0" >380.50</td>
#       <td id="T_f54be_row6_col1" class="data row6 col1" >30.10</td>
#       <td id="T_f54be_row6_col2" class="data row6 col2" >1.84</td>
#       <td id="T_f54be_row6_col3" class="data row6 col3" >362.23</td>
#       <td id="T_f54be_row6_col4" class="data row6 col4" >358.95</td>
#       <td id="T_f54be_row6_col5" class="data row6 col5" >1.47</td>
#       <td id="T_f54be_row6_col6" class="data row6 col6" >1.33</td>
#       <td id="T_f54be_row6_col7" class="data row6 col7" >363.43</td>
#       <td id="T_f54be_row6_col8" class="data row6 col8" >360.73</td>
#       <td id="T_f54be_row6_col9" class="data row6 col9" >26.26</td>
#       <td id="T_f54be_row6_col10"

# %%
results_iter4 = pd.read_csv('iter4_results1000.csv')
results_iter4.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_cfeb6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfeb6_level0_col0" class="col_heading level0 col0" >Num_Steps</th>
#       <th id="T_cfeb6_level0_col1" class="col_heading level0 col1" >Median_Error</th>
#       <th id="T_cfeb6_level0_col2" class="col_heading level0 col2" >Median_CEP</th>
#       <th id="T_cfeb6_level0_col3" class="col_heading level0 col3" >Median_X</th>
#       <th id="T_cfeb6_level0_col4" class="col_heading level0 col4" >Median_Y</th>
#       <th id="T_cfeb6_level0_col5" class="col_heading level0 col5" >MAD_X</th>
#       <th id="T_cfeb6_level0_col6" class="col_heading level0 col6" >MAD_Y</th>
#       <th id="T_cfeb6_level0_col7" class="col_heading level0 col7" >Mean_X</th>
#       <th id="T_cfeb6_level0_col8" class="col_heading level0 col8" >Mean_Y</th>
#       <th id="T_cfeb6_level0_col9" class="col_heading level0 col9" >Std_X</th>
#       <th id="T_cfeb6_level0_col10" class="col_heading level0 col10" >Std_Y</th>
#       <th id="T_cfeb6_level0_col11" class="col_heading level0 col11" >Distance_Moved</th>
#       <th id="T_cfeb6_level0_col12" class="col_heading level0 col12" >TotalReward</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfeb6_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_cfeb6_row0_col0" class="data row0 col0" >1000.00</td>
#       <td id="T_cfeb6_row0_col1" class="data row0 col1" >1000.00</td>
#       <td id="T_cfeb6_row0_col2" class="data row0 col2" >1000.00</td>
#       <td id="T_cfeb6_row0_col3" class="data row0 col3" >1000.00</td>
#       <td id="T_cfeb6_row0_col4" class="data row0 col4" >1000.00</td>
#       <td id="T_cfeb6_row0_col5" class="data row0 col5" >1000.00</td>
#       <td id="T_cfeb6_row0_col6" class="data row0 col6" >1000.00</td>
#       <td id="T_cfeb6_row0_col7" class="data row0 col7" >1000.00</td>
#       <td id="T_cfeb6_row0_col8" class="data row0 col8" >1000.00</td>
#       <td id="T_cfeb6_row0_col9" class="data row0 col9" >1000.00</td>
#       <td id="T_cfeb6_row0_col10" class="data row0 col10" >1000.00</td>
#       <td id="T_cfeb6_row0_col11" class="data row0 col11" >1000.00</td>
#       <td id="T_cfeb6_row0_col12" class="data row0 col12" >1000.00</td>
#     </tr>
#     <tr>
#       <th id="T_cfeb6_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_cfeb6_row1_col0" class="data row1 col0" >115.49</td>
#       <td id="T_cfeb6_row1_col1" class="data row1 col1" >14.10</td>
#       <td id="T_cfeb6_row1_col2" class="data row1 col2" >1.33</td>
#       <td id="T_cfeb6_row1_col3" class="data row1 col3" >350.97</td>
#       <td id="T_cfeb6_row1_col4" class="data row1 col4" >349.73</td>
#       <td id="T_cfeb6_row1_col5" class="data row1 col5" >0.93</td>
#       <td id="T_cfeb6_row1_col6" class="data row1 col6" >0.86</td>
#       <td id="T_cfeb6_row1_col7" class="data row1 col7" >350.34</td>
#       <td id="T_cfeb6_row1_col8" class="data row1 col8" >349.21</td>
#       <td id="T_cfeb6_row1_col9" class="data row1 col9" >21.83</td>
#       <td id="T_cfeb6_row1_col10" class="data row1 col10" >22.78</td>
#       <td id="T_cfeb6_row1_col11" class="data row1 col11" >7702.51</td>
#       <td id="T_cfeb6_row1_col12" class="data row1 col12" >-460.18</td>
#     </tr>
#     <tr>
#       <th id="T_cfeb6_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_cfeb6_row2_col0" class="data row2 col0" >110.54</td>
#       <td id="T_cfeb6_row2_col1" class="data row2 col1" >18.99</td>
#       <td id="T_cfeb6_row2_col2" class="data row2 col2" >0.54</td>
#       <td id="T_cfeb6_row2_col3" class="data row2 col3" >16.70</td>
#       <td id="T_cfeb6_row2_col4" class="data row2 col4" >17.19</td>
#       <td id="T_cfeb6_row2_col5" class="data row2 col5" >0.51</td>
_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_cfeb6_row6_col0" class="data row6 col0" >140.00</td>
#       <td id="T_cfeb6_row6_col1" class="data row6 col1" >16.88</td>
#       <td id="T_cfeb6_row6_col2" class="data row6 col2" >1.72</td>
#       <td id="T_cfeb6_row6_col3" class="data row6 col3" >356.39</td>
#       <td id="T_cfeb6_row6_col4" class="data row6 col4" >355.25</td>
#       <td id="T_cfeb6_row6_col5" class="data row6 col5" >1.26</td>
#       <td id="T_cfeb6_row6_col6" class="data row6 col6" >1.18</td>
#       <td id="T_cfeb6_row6_col7" class="data row6 col7" >357.05</td>
#       <td id="T_cfeb6_row6_col8" class="data row6 col8" >355.62</td>
#       <td id="T_cfeb6_row6_col9" class="data row6 col9" >13.27</td>
#       <td id="T_cfeb6_row6_col10" class="data row6 c

# %%
# Plot Results
plt.scatter(350,350,color='red', label='True Target Location', marker='x',s=200)

mean_num_steps = results_iter1['Num_Steps'].mean()
mean_median_error = results_iter1['Median_Error'].mean()
mean_median_cep = results_iter1['Median_CEP'].mean()
mean_median_x = results_iter1['Median_X'].mean()
mean_median_y = results_iter1['Median_Y'].mean()
mean_mad_x = results_iter1['MAD_X'].mean()
mean_mad_y = results_iter1['MAD_Y'].mean()

# Plot circle using MAD deviations of x & y values
radius = mean_median_cep
median_cep_legend1 = f'Median CEP Iteration 1 \nMean Error: ({np.round(mean_median_error,1)})'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='blue', facecolor='none', linestyle='-', linewidth=2, label=median_cep_legend1)
plt.gca().add_patch(circle_median)

mean_num_steps = results_iter2['Num_Steps'].mean()
mean_median_error = results_iter2['Median_Error'].mean()
mean_median_cep = results_iter2['Median_CEP'].mean()
mean_median_x = results_iter2['Median_X'].mean()
mean_median_y = results_iter2['Median_Y'].mean()
mean_mad_x = results_iter2['MAD_X'].mean()
mean_mad_y = results_iter2['MAD_Y'].mean()

# Plot circle using MAD deviations of x & y values
radius = mean_median_cep
median_cep_legend2 = f'Median CEP Iteration 2 \nMean Error: ({np.round(mean_median_error,1)})'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='red', facecolor='none', linestyle='-', linewidth=2, label=median_cep_legend2)
plt.gca().add_patch(circle_median)

mean_num_steps = results_iter3['Num_Steps'].mean()
mean_median_error = results_iter3['Median_Error'].mean()
mean_median_cep = results_iter3['Median_CEP'].mean()
mean_median_x = results_iter3['Median_X'].mean()
mean_median_y = results_iter3['Median_Y'].mean()
mean_mad_x = results_iter3['MAD_X'].mean()
mean_mad_y = results_iter3['MAD_Y'].mean()

# Plot circle using MAD deviations of x & y values
radius = mean_median_cep
median_cep_legend3 = f'Median CEP Iteration 3 \nMean Error: ({np.round(mean_median_error,1)})'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='black', facecolor='none', linestyle='-', linewidth=2, label=median_cep_legend3)
plt.gca().add_patch(circle_median)


mean_num_steps = results_iter4['Num_Steps'].mean()
mean_median_error = results_iter4['Median_Error'].mean()
mean_median_cep = results_iter4['Median_CEP'].mean()
mean_median_x = results_iter4['Median_X'].mean()
mean_median_y = results_iter4['Median_Y'].mean()
mean_mad_x = results_iter4['MAD_X'].mean()
mean_mad_y = results_iter4['MAD_Y'].mean()

# Plot circle using MAD deviations of x & y values
radius = mean_median_cep
median_cep_legend4 = f'Median CEP Iteration 4 \nMean Error: ({np.round(mean_median_error,1)})'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='green', facecolor='none', linestyle='-', linewidth=2, label=median_cep_legend4)
plt.gca().add_patch(circle_median)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Median CEP by Iteration')
plt.legend(
    loc='lower center', 
    bbox_to_anchor=(0.5, -.35),
    ncol=3, 
)
plt.grid(True)
plt.axis('equal')  # Equal aspect ratio
plt.show()

# %% [markdown]
# ## 10000 Runs

# %%
results_iter1 = pd.read_csv('iter1_results10000_fin.csv')
results_iter1.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T
row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_11ce3_row3_col2" class="data row3 col2" >0.02</td>
#       <td id="T_11ce3_row3_col3" class="data row3 col3" >-1764.57</td>
#       <td id="T_11ce3_row3_col4" class="data row3 col4" >-5138.72</td>
#       <td id="T_11ce3_row3_col5" class="data row3 col5" >0.01</td>
#       <td id="T_11ce3_row3_col6" class="data row3 col6" >0.01</td>
#       <td id="T_11ce3_row3_col7" class="data row3 col7" >-14924.57</td>
#       <td id="T_11ce3_row3_col8" class="data row3 col8" >-65537.04</td>
#       <td id="T_11ce3_row3_col9" class="data row3 col9" >0.06</td>
#       <td id="T_11ce3_row3_col10" class="data row3 col10" >0.03</td>
#       <td id="T_11ce3_row3_col11" class="data row3 col11" >2864.99</td>
#       <td id="T_11ce3_row3_col12" class="data row3 col12" >-1414.00</td>
#     </tr>
#     <tr>
#       <th id="T_11ce3_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_11ce3_row4_col0" class="data row4 col0" >46.00</td>
#       <td id="T_11ce3_row4_col1" class="data row4 col1" >3.31</td>
#       <td id="T_11ce3_row4_col2" class="data row4 col2" >1.00</td>
#       <td id="T_11ce3_row4_col3" class="data row4 col3" >344.82</td>
#       <td id="T_11ce3_row4_col4" class="data row4 col4" >343.92</td>
#       <td id="T_11ce3_row4_col5" class="data row4 col5" >0.53</td>
#       <td id="T_11ce3_row4_col6" class="data row4 col6" >0.58</td>
#       <td id="T_11ce3_row4_col7" class="data row4 col7" >343.97</td>
#       <td id="T_11ce3_row4_col8" class="data row4 col8" >343.26</td>
#       <td id="T_11ce3_row4_col9" class="data row4 col9" >2.60</td>
#       <td id="T_11ce3_row4_col10" class="data row4 col10" >2.67</td>
#       <td id="T_11ce3_row4_col11" class="data row4 col11" >6340.95</td>
#       <td id="T_11ce3_row4_col12" class="data row4 col12" >15.50</td>
#     </tr>
#     <tr>
#       <th id="T_11ce3_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_11ce3_row5_col0" class="data row5 col0" >85.00</td>
#       <td id="T_11ce3_row5_col1" class="data row5 col1" >7.38</td>
#       <td id="T_11ce3_row5_col2" class="data row5 col2" >1.41</td>
#       <td id="T_11ce3_row5_col3" class="data row5 col3" >349.87</td>
#       <td id="T_11ce3_row5_col4" class="data row5 col4" >350.10</td>
#       <td id="T_11ce3_row5_col5" class="data row5 col5" >0.84</td>
#       <td id="T_11ce3_row5_col6" class="data row5 col6" >0.92</td>
#       <td id="T_11ce3_row5_col7" class="data row5 col7" >349.88</td>
#       <td id="T_11ce3_row5_col8" class="data row5 col8" >350.12</td>
#       <td id="T_11ce3_row5_col9" class="data row5 col9" >5.23</td>
#       <td id="T_11ce3_row5_col10" class="data row5 col10" >5.20</td>
#       <td id="T_11ce3_row5_col11" class="data row5 col11" >7431.46</td>
#       <td id="T_11ce3_row5_col12" class="data row5 col12" >76.00</td>
#     </tr>
#     <tr>
#       <th id="T_11ce3_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_11ce3_row6_col0" class="data row6 col0" >146.00</td>
#       <td id="T_11ce3_row6_col1" class="data row6 col1" >14.34</td>
#       <td id="T_11ce3_row6_col2" class="data row6 col2" >1.73</td>
#       <td id="T_11ce3_row6_col3" class="data row6 col3" >355.28</td>
#       <td id="T_11ce3_row6_col4" class="data row6 col4" >356.32</td>
#       <td id="T_11ce3_row6_col5" class="data row6 col5" >1.18</td>
#       <td id="T_11ce3_row6_col6" class="data row6 col6" >1.27</td>
#       <td id="T_11ce3_row6_col7" class="data row6 col7" >356.09</td>
#       <td id="T_11ce3_row6_col8" class="data row6 col8" >357.04</td>
#       <td id="T_11ce3_row6_col9" class="data row6 col9" >12.74</td>
#       <td id="T_11ce3_ro

# %%
results_iter2 = pd.read_csv('iter2_results10000_fin.csv')
results_iter2.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_
describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_818df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_818df_level0_col0" class="col_heading level0 col0" >Num_Steps</th>
#       <th id="T_818df_level0_col1" class="col_heading level0 col1" >Median_Error</th>
#       <th id="T_818df_level0_col2" class="col_heading level0 col2" >Median_CEP</th>
#       <th id="T_818df_level0_col3" class="col_heading level0 col3" >Median_X</th>
#       <th id="T_818df_level0_col4" class="col_heading level0 col4" >Median_Y</th>
#       <th id="T_818df_level0_col5" class="col_heading level0 col5" >MAD_X</th>
#       <th id="T_818df_level0_col6" class="col_heading level0 col6" >MAD_Y</th>
#       <th id="T_818df_level0_col7" class="col_heading level0 col7" >Mean_X</th>
#       <th id="T_818df_level0_col8" class="col_heading level0 col8" >Mean_Y</th>
#       <th id="T_818df_level0_col9" class="col_heading level0 col9" >Std_X</th>
#       <th id="T_818df_level0_col10" class="col_heading level0 col10" >Std_Y</th>
#       <th id="T_818df_level0_col11" class="col_heading level0 col11" >Distance_Moved</th>
#       <th id="T_818df_level0_col12" class="col_heading level0 col12" >TotalReward</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_818df_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_818df_row0_col0" class="data row0 col0" >10000.00</td>
#       <td id="T_818df_row0_col1" class="data row0 col1" >10000.00</td>
#       <td id="T_818df_row0_col2" class="data row0 col2" >10000.00</td>
#       <td id="T_818df_row0_col3" class="data row0 col3" >10000.00</td>
#       <td id="T_818df_row0_col4" class="data row0 col4" >10000.00</td>
#       <td id="T_818df_row0_col5" class="data row0 col5" >10000.00</td>
#       <td id="T_818df_row0_col6" class="data row0 col6" >10000.00</td>
#       <td id="T_818df_row0_col7" class="data row0 col7" >10000.00</td>
#       <td id="T_818df_row0_col8" class="data row0 col8" >10000.00</td>
#       <td id="T_818df_row0_col9" class="data row0 col9" >10000.00</td>
#       <td id="T_818df_row0_col10" class="data row0 col10" >10000.00</td>
#       <td id="T_818df_row0_col11" class="data row0 col11" >10000.00</td>
#       <td id="T_818df_row0_col12" class="data row0 col12" >10000.00</td>
#     </tr>
#     <tr>
#       <th id="T_818df_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_818df_row1_col0" class="data row1 col0" >219.84</td>
#       <td id="T_818df_row1_col1" class="data row1 col1" >19.94</td>
#       <td id="T_818df_row1_col2" class="data row1 col2" >6.74</td>
#       <td id="T_818df_row1_col3" class="data row1 col3" >351.80</td>
#       <td id="T_818df_row1_col4" class="data row1 col4" >353.63</td>
#       <td id="T_818df_row1_col5" class="data row1 col5" >3.72</td>
#       <td id="T_818df_row1_col6" class="data row1 col6" >4.98</td>
#       <td id="T_818df_row1_col7" class="data row1 col7" >351.64</td>
#       <td id="T_818df_row1_col8" class="data row1 col8" >349.80</td>
#       <td id="T_818df_row1_col9" class="data row1 col9" >90.73</td>
#       <td id="T_818df_row1_col10" class="data row1 col10" >107.63</td>
#       <td id="T_818df_row1_col11" class="data row1 col11" >8490.40</td>
#       <td id="T_818df_row1_col12" class="data row1 col12" >182.86</td>
#     </tr>
#     <tr>
#       <th id="T_818df_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_818df_row2_col0" class="data row2 col0" >247.29</td>
#       <td id="T_818df_row2_col1" class="data row2 col1" >28.61</td>
#       <td id="T_818df_row2_col2" class="data row2 col2" >56.42</td>
#       <td id="T_818df_row2_col3" class="data row2 col3" >24.59</td>
#       <td id="T_818df_row2_col4" class="data row2 col4" >111.93</td>
#       <td id="T_818df_row2_col5" class="data row2 col5" >19.60</td>
#       <td id="T_818df_row2_col6" class="data row2 col6" >52.97</td>
#       <td id="T_818df_row2_col7" class="data row2 col7" >374.78</td>
#       <td id="T_818df_row2_col8" class="data row2 col8" >479.21</td>
#       <td id="T_818df_row2_col9" class="data row2 col9" >1787.06</td>
#       <td id="T_818df_row2_col10" class="data row2 col10" >1622.86</td>
#       <td id="T_818df_row2_col11" class="data row2 col11" >2059.70</td>
#       <td id="T_818df_row2_col12" class="data row2 col12" >265.33</td>
#     </tr>
#     <tr>
#       <th id="T_818df_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_818df_row3_col0" class="data row3 col0" >1.00</td>
#       <td id="T_818df_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_818df_row3_col2" class="data row3 col2" >0.01</td>
#       <td id="T_818df_row3_col3" class="data row3 col3" >-48.54</td>
#       <td id="T_818df_row3_col4" class="data row3 col4" >-410.41</td>
#       <td id="T_818df_row3_col5" class="data row3 col5" >0.00</td>
#       <td id="T_818df_row3_col6" class="data row3 col6" >0.00</td>
#       <td id="T_818df_row3_col7" class="data row3 col7" >-14938.45</td>
#       <td id="T_818df_row3_col8" class="data row3 col8" >-39948.36</td>
#       <td id="T_818df_row3_col9" class="data row3 col9" >0.07</td>
#       <td id="T_818df_row3_col10" class="data row3 col10" >0.01</td>
#       <td id="T_818df_row3_col11" class="data row3 col11" >3233.13</td>
#       <td id="T_818df_row3_col12" class="data row3 col12" >-907.00</td>
#     </tr>
#     <tr>
#       <th id="T_818df_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_818df_row4_col0" class="data row4 col0" >60.00</td>
#       <td id="T_818df_row4_col1" class="data row4 col1" >5.60</td>
#       <td id="T_818df_row4_col2" class="data row4 col2" >1.00</td>
#       <td id="T_818df_row4_col3" class="data row4 col3" >342.25</td>
#       <td id="T_818df_row4_col4" class="data row4 col4" >343.64</td>
#       <td id="T_818df_row4_col5" class="data row4 col5" >0.61</td>
#       <td id="T_818df_row4_col6" class="data row4 col6" >0.51</td>
#       <td id="T_818df_row4_col7" class="data row4 col7" >341.37</td>
#       <td id="T_818df_row4_col8" class="data row4 col8" >342.77</td>
#       <td id="T_818df_row4_col9" class="data row4 col9" >2.88</td>
#       <td id="T_818df_row4_col10" class="data row4 col10" >2.70</td>
#       <td id="T_818df_row4_col11" class="data row4 col11" >7064.47</td>
#       <td id="T_818df_row4_col12" class="data row4 col12" >57.00</td>
#     </tr>
#     <tr>
#       <th id="T_818df_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_818df_row5_col0" class="data row5 col0" >126.00</td>
#       <td id="T_818df_row5_col1" class="data row5 col1" >12.36</td>
#       <td id="T_818df_row5_col2" class="data row5 col2" >1.43</td>
#       <td id="T_818df_row5_col3" class="data row5 col3" >350.69</td>
#       <td id="T_818df_row5_col4" class="data row5 col4" >350.56</td>
#       <td id="T_818df_row5_col5" class="data row5 col5" >0.96</td>
#       <td id="T_818df_row5_col6" class="data row5 col6" >0.83</td>
#       <td id="T_818df_row5_col7" class="data row5 col7" >350.81</td>
#       <td id="T_818df_row5_col8" class="data row5 col8" >350.68</td>
#       <td id="T_818df_row5_col9" class="data row5 col9" >5.92</td>
#       <td id="T_818df_row5_col10" class="data row5 col10" >5.89</td>
#       <td id="T_818df_row5_col11" class="data row5 col11" >8388.70</td>
#       <td id="T_818df_row5_col12" class="data row5 col12" >128.00</td>
#     </tr>
#     <tr>
#       <th id="T_818df_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_818df_row6_col0" class="data row6 col0" >270.00</td>
#       <td id="T_818df_row6_col1" class="data row6 col1" >24.03</td>
#       <td id="T_818df_row6_col2" class="data row6 col2" >1.76</td>
#       <td id="T_818df_row6_col3" class="data row6 col3" >359.68</td>
#       <td id="T_818df_row6_col4" class="data row6 col4" >358.00</td>
#       <td id="T_818df_row6_col5" class="data row6 col5" >1.34</td>
#       <td id="T_818df_row6_col6" class="data row6 col6" >1.21</td>
#       <td id="T_818df_row6_col7" class="data row6 col7" >360.75</td>
#       <td id="T_818df_row6_col8" class="data row6 col8" >359.27</td>
#       <td id="T_818df_row6_col9" class="data row6 col9" >16.10</td>
#       <td id="T_818df_row6

# %%
results_iter4 = pd.read_csv('iter4_1_bvm1_corr_results10000_fin.csv')
results_iter4.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_ef6bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef6bf_level0_col0" class="col_heading level0 col0" >Num_Steps</th>
#       <th id="T_ef6bf_level0_col1" class="col_heading level0 col1" >Median_Error</th>
#       <th id="T_ef6bf_level0_col2" class="col_heading level0 col2" >Median_CEP</th>
#       <th id="T_ef6bf_level0_col3" class="col_heading level0 col3" >Median_X</th>
#       <th id="T_ef6bf_level0_col4" class="col_heading level0 col4" >Median_Y</th>
#       <th id="T_ef6bf_level0_col5" class="col_heading level0 col5" >MAD_X</th>
#       <th id="T_ef6bf_level0_col6" class="col_heading level0 col6" >MAD_Y</th>
#       <th id="T_ef6bf_level0_col7" class="col_heading level0 col7" >Mean_X</th>
#       <th id="T_ef6bf_level0_col8" class="col_heading level0 col8" >Mean_Y</th>
#       <th id="T_ef6bf_level0_col9" class="col_heading level0 col9" >Std_X</th>
#       <th id="T_ef6bf_level0_col10" class="col_heading level0 col10" >Std_Y</th>
#       <th id="T_ef6bf_level0_col11" class="col_heading level0 col11" >Distance_Moved</th>
#       <th id="T_ef6bf_level0_col12" class="col_heading level0 col12" >TotalReward</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef6bf_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_ef6bf_row0_col0" class="data row0 col0" >10000.00</td>
#       <td id="T_ef6bf_row0_col1" class="data row0 col1" >10000.00</td>
#       <td id="T_ef6bf_row0_col2" class="data row0 col2" >10000.00</td>
#       <td id="T_ef6bf_row0_col3" class="data row0 col3" >10000.00</td>
#       <td id="T_ef6bf_row0_col4" class="data row0 col4" >10000.00</td>
#       <td id="T_ef6bf_row0_col5" class="data row0 col5" >10000.00</td>
#       <td id="T_ef6bf_row0_col6" class="data row0 col6" >10000.00</td>
#       <td id="T_ef6bf_row0_col7" class="data row0 col7" >10000.00</td>
#       <td id="T_ef6bf_row0_col8" class="data row0 col8" >10000.00</td>
#       <td id="T_ef6bf_row0_col9" class="data row0 col9" >10000.00</td>
#       <td id="T_ef6bf_row0_col10" class="data row0 col10" >10000.00</td>
#       <td id="T_ef6bf_row0_col11" class="data row0 col11" >10000.00</td>
#       <td id="T_ef6bf_row0_col12" class="data row0 col12" >10000.00</td>
#     </tr>
#     <tr>
#       <th id="T_ef6bf_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_ef6bf_row1_col0" class="data row1 col0" >129.19</td>
#       <td id="T_ef6bf_row1_col1" class="data row1 col1" >13.70</td>
#       <td id="T_ef6bf_row1_col2" class="data row1 col2" >2.38</td>
#       <td id="T_ef6bf_row1_col3" class="data row1 col3" >350.62</td>
#       <td id="T_ef6bf_row1_col4" class="data row1 col4" >349.64</td>
#       <td id="T_ef6bf_row1_col5" class="data row1 col5" >1.40</td>
#       <td id="T_ef6bf_row1_col6" class="data row1 col6" >1.73</td>
#       <td id="T_ef6bf_row1_col7" class="data row1 col7" >352.67</td>
#       <td id="T_ef6bf_row1_col8" class="data row1 col8" >350.70</td>
#       <td id="T_ef6bf_row1_col9" class="data row1 col9" >46.62</td>
#       <td id="T_ef6bf_row1_col10" class="data row1 col10" >47.84</td>
#       <td id="T_ef6bf_row1_col11" class="data row1 col11" >7740.50</td>
#       <td id="T_ef6bf_row1_col12" class="data row1 col12" >112.67</td>
#     </tr>
#     <tr>
#       <th id="T_ef6bf_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_ef6bf_row2_col0" class="data row2 col0" >143.90</td>
#       <td id="T_ef6bf_row2_col1" class="data row2 col1" >19.30</td>
#       <td id="T_ef6bf_row2_col2" class="data row2 col2" >29.67</td>
#       <td id="T_ef6bf_row2_col3" class="data row2 col3" >16.73</td>
#       <td id="T_ef6bf_row2_col4" class="data row2 col4" >20.89</td>
#       <td id="T_ef6bf_row2_col5" class="data row2 col5" >9.25</td>
#       <td id="T_ef6bf_row2_col6" class="data row2 col6" >28.20</td>
#       <td id="T_ef6bf_row2_col7" class="data row2 col7" >173.06</td>
#       <td id="T_ef6bf_row2_col8" class="data row2 col8" >164.40</td>
#       <td id="T_ef6bf_row2_col9" class="data row2 col9" >881.52</td>
#       <td id="T_ef6bf_row2_col10" class="data row2 col10" >769.26</td>
#       <td id="T_ef6bf_row2_col11" class="data row2 col11" >1923.34</td>
#       <td id="T_ef6bf_row2_col12" class="data row2 col12" >157.06</td>
#     </tr>
#     <tr>
#       <th id="T_
level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_ef6bf_row6_col0" class="data row6 col0" >154.00</td>
#       <td id="T_ef6bf_row6_col1" class="data row6 col1" >16.99</td>
#       <td id="T_ef6bf_row6_col2" class="data row6 col2" >1.73</td>
#       <td id="T_ef6bf_row6_col3" class="data row6 col3" >356.78</td>
#       <td id="T_ef6bf_row6_col4" class="data row6 col4" >355.91</td>
#       <td id="T_ef6bf_row6_col5" class="data row6 col5" >1.24</td>
#       <td id="T_ef6bf_row6_col6" class="data row6 col6" >1.21</td>
#       <td id="T_ef6bf_row6_col7" class="data row6 col7" >357.48</td>
#       <td id="T_ef6bf_row6_col8" class="data row6 col8" >356.40</td>
#       <td id="T_ef6bf_row6_col9" class="data row6 col9" >12.40</td>
#       <td id="T_ef6bf_row6_col10" c

# %%
# Plot Results

import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
from matplotlib.lines import Line2D
import numpy as np

ghost = plt.Line2D([], [], color='none', label='')

plt.scatter(350,350,color='red', label='Target Location', marker='x',s=200)

mean_num_steps = results_iter1['Num_Steps'].mean()
mean_median_error = results_iter1['Median_Error'].mean()
mean_median_cep = results_iter1['Median_CEP'].mean()
mean_median_x = results_iter1['Median_X'].mean()
mean_median_y = results_iter1['Median_Y'].mean()
mean_mad_x = results_iter1['MAD_X'].mean()
mean_mad_y = results_iter1['MAD_Y'].mean()

# Plot circle using MAD deviations of x & y values
radius = mean_median_cep
median_cep_legend1 = f'Iteration 1 Median CEP \nMean Error: ({np.round(mean_median_error,1)})'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='red', facecolor='none', linestyle=':', linewidth=2, label=median_cep_legend1)
plt.gca().add_patch(circle_median)

mean_num_steps = results_iter2['Num_Steps'].mean()
mean_median_error = results_iter2['Median_Error'].mean()
mean_median_cep = results_iter2['Median_CEP'].mean()
mean_median_x = results_iter2['Median_X'].mean()
mean_median_y = results_iter2['Median_Y'].mean()
mean_mad_x = results_iter2['MAD_X'].mean()
mean_mad_y = results_iter2['MAD_Y'].mean()

# Plot circle using MAD deviations of x & y values
radius = mean_median_cep
median_cep_legend2 = f'Iteration 2 Median CEP \nMean Error: ({np.round(mean_median_error,1)})'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='blue', facecolor='none', linestyle='-.', linewidth=2, label=median_cep_legend2)
plt.gca().add_patch(circle_median)

mean_num_steps = results_iter3['Num_Steps'].mean()
mean_median_error = results_iter3['Median_Error'].mean()
mean_median_cep = results_iter3['Median_CEP'].mean()
mean_median_x = results_iter3['Median_X'].mean()
mean_median_y = results_iter3['Median_Y'].mean()
mean_mad_x = results_iter3['MAD_X'].mean()
mean_mad_y = results_iter3['MAD_Y'].mean()

# Plot circle using MAD deviations of x & y values
radius = mean_median_cep
median_cep_legend3 = f'Iteration 3 Median CEP \nMean Error: ({np.round(mean_median_error,1)})'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='green', facecolor='none', linestyle='--', linewidth=2, label=median_cep_legend3)
plt.gca().add_patch(circle_median)

mean_num_steps = results_iter4['Num_Steps'].mean()
mean_median_error = results_iter4['Median_Error'].mean()
mean_median_cep = results_iter4['Median_CEP'].mean()
mean_median_x = results_iter4['Median_X'].mean()
mean_median_y = results_iter4['Median_Y'].mean()
mean_mad_x = results_iter4['MAD_X'].mean()
mean_mad_y = results_iter4['MAD_Y'].mean()

# Plot circle using MAD deviations of x & y values
radius = mean_median_cep
median_cep_legend4 = f'Iteration 4 Median CEP \nMean Error: ({np.round(mean_median_error,1)})'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='black', facecolor='none', linestyle='-', linewidth=2, label=median_cep_legend4)
plt.gca().add_patch(circle_median)

# Create custom legend entries for the line styles
legend_entries = [
    Line2D([0], [0], color='red', linestyle=':', linewidth=2, label=median_cep_legend1),
    Line2D([0], [0], color='blue', linestyle='-.', linewidth=2, label=median_cep_legend2),
    Line2D([0], [0], color='green', linestyle='--', linewidth=2, label=median_cep_legend3),
    Line2D([0], [0], color='black', linestyle='-', linewidth=2, label=median_cep_legend4)
]

# True Target Location
true_target = Line2D([0], [0], color='red', marker='x', markersize=10, linewidth=0, label='Target Location')

# Configure legend
plt.legend(
    handles=[true_target] +[ghost] + legend_entries,  # Combine the target and other legend entries
    loc='lower center',
    bbox_to_anchor=(0.5, -0.35),  # Adjust as necessary for your layout
    ncol=3,
    frameon=True
)

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Median Confidence Regions by Iteration')
plt.grid(True)
plt.axis('equal')  # Equal aspect ratio
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = np.arctan(x)

# Plotting with different line styles
plt.plot(x, y4, linestyle=':', label='Iter 1')    # Dotted line
plt.plot(x, y3, linestyle='-.', label='Iter 2')  # Dash-dot line

plt.plot(x, y2, linestyle='--', label='Iter 3')   # Dashed line

plt.plot(x, y1, linestyle='-', label='Iter 4')     # Solid line

plt.legend()
plt.show()

# %% [markdown]
# ## Plot Histograms and Fit Gamma Distributions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gamma

# List of datasets
datasets = ['iter1_results10000_fin.csv', 'iter2_results10000_fin.csv', 'iter3_1_bvm1_corr_results10000_fin.csv', 'iter4_1_bvm1_corr_results10000_fin.csv']
colors = ['red', 'blue', 'green', 'purple']  # Different colors for each dataset
labels = ['Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4']

fig, ax = plt.subplots()

# Loop over datasets
for data_file, color, label in zip(datasets, colors, labels):
    # Load data
    data = pd.read_csv(data_file)
    values = data['TotalReward'].values

    # Fit the gamma distribution
    params = gamma.fit(values)
    alpha, loc, scale = params
    mean = gamma.mean(alpha, loc, scale)

    # Plot the fitted gamma distribution
    x = np.linspace(min(values), max(values), 1000)
    pdf_fitted = gamma.pdf(x, alpha, loc, scale)
    ax.plot(x, pdf_fitted, '-', color=color, label=f'{label}: α={alpha:.2f}, β={scale:.2f}, Mean={mean:.2f}')

# Add legend, labels, and title
ax.legend()
ax.set_xscale('log')

#ax.set_xlabel('Median_Error')
ax.set_ylabel('Density')
ax.set_title('Comparison of Gamma Distributions Across Four Datasets')

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# List of datasets
datasets = ['iter1_results10000_fin.csv', 'iter2_results10000_fin.csv', 'iter3_1_bvm1_corr_results10000_fin.csv', 'iter4_1_bvm1_corr_results10000_fin.csv']
colors = ['red', 'blue', 'green', 'purple']  # Different colors for each dataset
labels = ['Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4']

fig, ax = plt.subplots()

# Loop over datasets
for data_file, color, label in zip(datasets, colors, labels):
    # Load data
    data = pd.read_csv(data_file)
    values = data['Median_CEP'].values

    # Fit the normal distribution
    mu, sigma = norm.fit(values)

    # Plot the fitted normal distribution
    x = np.linspace(min(values), max(values), 1000)
    pdf_fitted = norm.pdf(x, mu, sigma)
    ax.plot(x, pdf_fitted, '-', color=color, label=f'{label}: μ={mu:.2f}, σ={sigma:.2f}')

# Set x-axis to logarithmic scale
ax.set_xscale('log')

# Add legend, labels, and title
ax.legend()
ax.set_xlim([1, np.max(values)])

ax.set_xlabel('Median_CEP (log scale)')
ax.set_ylabel('Density')
ax.set_title('Comparison of Normal Distributions Across Four Datasets')

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# List of datasets
datasets = ['iter1_results10000_fin.csv', 'iter2_results10000_fin.csv', 'iter3_1_bvm1_corr_results10000_fin.csv', 'iter4_1_bvm1_corr_results10000_fin.csv']
colors = ['red', 'blue', 'green', 'purple']  # Different colors for each dataset
labels = ['Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4']

fig, ax = plt.subplots()

# Loop over datasets
for data_file, color, label in zip(datasets, colors, labels):
    # Load data
    data = pd.read_csv(data_file)
    values = data['Median_Error'].values

    # Fit the normal distribution
    mu, sigma = norm.fit(values)

    # Plot the fitted normal distribution
    x = np.linspace(min(values), max(values), 1000)
    pdf_fitted = norm.pdf(x, mu, sigma)
    ax.plot(x, pdf_fitted, '-', color=color, label=f'{label}: μ={mu:.2f}, σ={sigma:.2f}')

# Set x-axis to logarithmic scale
ax.set_xscale('log')

# Add legend, labels, and title
ax.legend()
ax.set_xlim([1, np.max(values)])

ax.set_xlabel('Median_Error (log scale)')
ax.set_ylabel('Density')
ax.set_title('Comparison of Normal Distributions Across Four Datasets')

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# List of datasets
datasets = ['iter1_results10000_fin.csv', 'iter2_results10000_fin.csv', 'iter3_1_bvm1_corr_results10000_fin.csv', 'iter4_1_bvm1_corr_results10000_fin.csv']
colors = ['red', 'blue', 'green', 'purple']  # Different colors for each dataset
labels = ['Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4']

fig, ax = plt.subplots()

# Loop over datasets
for data_file, color, label in zip(datasets, colors, labels):
    # Load data
    data = pd.read_csv(data_file)
    values = data['TotalReward'].values

    # Fit the normal distribution
    mu, sigma = norm.fit(values)

    # Plot the fitted normal distribution
    x = np.linspace(min(values), max(values), 1000)
    pdf_fitted = norm.pdf(x, mu, sigma)
    ax.plot(x, pdf_fitted, '-', color=color, label=f'{label}: μ={mu:.2f}, σ={sigma:.2f}')

# Set x-axis to logarithmic scale
ax.set_xscale('log')

# Add legend, labels, and title
ax.legend()
ax.set_xlim([1, np.max(values)])

ax.set_xlabel('TotalReward (log scale)')
ax.set_ylabel('Density')
ax.set_title('Comparison of Normal Distributions Across Four Datasets')

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# List of datasets
datasets = ['iter1_results10000_fin.csv', 'iter2_results10000_fin.csv', 'iter3_1_bvm1_corr_results10000_fin.csv', 'iter4_1_bvm1_corr_results10000_fin.csv']
colors = ['red', 'blue', 'green', 'purple']  # Different colors for each dataset
labels = ['Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4']

fig, ax = plt.subplots()

# Loop over datasets
for data_file, color, label in zip(datasets, colors, labels):
    # Load data
    data = pd.read_csv(data_file)
    values = data['Distance_Moved'].values

    # Fit the normal distribution
    mu, sigma = norm.fit(values)

    # Plot the fitted normal distribution
    x = np.linspace(min(values), max(values), 1000)
    pdf_fitted = norm.pdf(x, mu, sigma)
    ax.plot(x, pdf_fitted, '-', color=color, label=f'{label}: μ={mu:.2f}, σ={sigma:.2f}')

# Set x-axis to logarithmic scale
ax.set_xscale('log')

# Add legend, labels, and title
ax.legend()
#ax.set_xlim([1, np.max(values)])

ax.set_xlabel('Distance_Moved (log scale)')
ax.set_ylabel('Density')
ax.set_title('Comparison of Normal Distributions Across Four Datasets')

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# List of datasets
datasets = ['iter1_results10000_fin.csv', 'iter2_results10000_fin.csv', 'iter3_1_bvm1_corr_results10000_fin.csv', 'iter4_1_bvm1_corr_results10000_fin.csv']
colors = ['red', 'blue', 'green', 'purple']  # Different colors for each dataset
labels = ['Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4']

fig, ax = plt.subplots()

# Loop over datasets
for data_file, color, label in zip(datasets, colors, labels):
    # Load data
    data = pd.read_csv(data_file)
    values = data['Num_Steps'].values

    # Fit the normal distribution
    mu, sigma = norm.fit(values)

    # Plot the fitted normal distribution
    x = np.linspace(min(values), max(values), 1000)
    pdf_fitted = norm.pdf(x, mu, sigma)
    ax.plot(x, pdf_fitted, '-', color=color, label=f'{label}: μ={mu:.2f}, σ={sigma:.2f}')

# Set x-axis to logarithmic scale
ax.set_xscale('log')

# Add legend, labels, and title
ax.legend()
#ax.set_xlim([1, np.max(values)])

ax.set_xlabel('Num_Steps (log scale)')
ax.set_ylabel('Density')
ax.set_title('Comparison of Normal Distributions Across Four Datasets')

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define dataset files and column types
dataset_files = [
    'iter1_results10000_fin.csv',
    'iter2_results10000_fin.csv',
    'iter3_1_bvm1_corr_results10000_fin.csv',
    'iter4_1_bvm1_corr_results10000_fin.csv'
]
data_columns = {
    'Median_CEP': 'Median CEP',
    'Median_Error': 'Median Error',
    'Num_Steps': 'Number of Steps',
    'Distance_Moved': 'Distance Moved'
}
colors = ['red', 'blue', 'green', 'purple']  # Different colors for each dataset
labels = ['Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4']  # Legend labels

# Setup a 2x2 subplot grid
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.flatten()

# Loop through each data type and plot on the corresponding subplot
for ax, (key, label) in zip(axes, data_columns.items()):
    for file, color, leg_label in zip(dataset_files, colors, labels):
        # Load data from each file
        data = pd.read_csv(file)
        values = data[key].values

        # Fit the normal distribution to the specified column
        mu, sigma = norm.fit(values)
        mu, sigma = round(mu), round(sigma)  # Round parameters to the nearest integer

        # Generate x values for plotting
        x = np.logspace(np.log10(max(1, np.min(values))), np.log10(np.max(values)), 1000)
        pdf_fitted = norm.pdf(x, mu, sigma)

        # Plot the fitted normal distribution for each dataset
        ax.plot(x, pdf_fitted, '-', color=color, label=f'{leg_label}: μ={mu}, σ={sigma}')

        # Set the x-axis to logarithmic scale and dynamically set its limits based on the subplot
        ax.set_xscale('log')
        if key == 'Distance_Moved':
            ax.set_xlim([np.min(values), np.max(values)])
        else:
            ax.set_xlim([1, np.max(values)])

    # Labels and title for each subplot
    #ax.set_title(f'Fit of {label}')
    ax.set_xlabel(label)
    ax.set_ylabel('Density')
    ax.legend()

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
from scipy.stats import norm

# Set global parameters for font size to ensure readability
rcParams.update({'font.size': 8, 'axes.labelsize': 8, 'axes.titlesize': 9, 'legend.fontsize': 6, 'xtick.labelsize': 7, 'ytick.labelsize': 7})

# Define dataset files and column types
dataset_files = [
    'iter1_results10000_fin.csv',
    'iter2_results10000_fin.csv',
    'iter3_1_bvm1_corr_results10000_fin.csv',
    'iter4_1_bvm1_corr_results10000_fin.csv'
]
data_columns = {
    'Median_CEP': 'Median CEP',
    'Median_Error': 'Median Error',
    'Num_Steps': 'Number of Steps',
    'Distance_Moved': 'Distance Moved'
}
colors = ['red', 'blue', 'green', 'purple']  # Different colors for each dataset
labels = ['Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4']  # Legend labels

# Setup a 2x2 subplot grid, figure size is set to fit 3.5 inches by 3 inches
fig, axes = plt.subplots(2, 2, figsize=(3.5, 3), dpi=300)  # Increase DPI for better resolution in small plots
axes = axes.flatten()

# Loop through each data type and plot on the corresponding subplot
for ax, (key, label) in zip(axes, data_columns.items()):
    for file, color, leg_label in zip(dataset_files, colors, labels):
        # Load data from each file
        data = pd.read_csv(file)
        values = data[key].values

        # Fit the normal distribution to the specified column
        mu, sigma = norm.fit(values)
        mu, sigma = round(mu), round(sigma)  # Round parameters to the nearest integer

        # Generate x values for plotting
        x = np.logspace(np.log10(max(1, np.min(values))), np.log10(np.max(values)), 1000)
        pdf_fitted = norm.pdf(x, mu, sigma)

        # Plot the fitted normal distribution for each dataset
        ax.plot(x, pdf_fitted, '-', color=color, label=f'{leg_label}: μ={mu}, σ={sigma}')

        # Set the x-axis to logarithmic scale and dynamically set its limits based on the subplot
        ax.set_xscale('log')
        if key == 'Distance_Moved':
            ax.set_xlim([np.min(values), np.max(values)])
        else:
            ax.set_xlim([1, np.max(values)])

    # Labels and title for each subplot
    ax.set_title(f'Fit of {label}')
    ax.set_xlabel(label)
    ax.set_ylabel('Density')
    ax.legend()

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
from scipy.stats import norm

# Set global parameters for font size to ensure readability
rcParams.update({'font.size': 8, 'axes.labelsize': 8, 'axes.titlesize': 9, 'legend.fontsize': 5, 'xtick.labelsize': 7, 'ytick.labelsize': 7})

# Define dataset files and column types
dataset_files = [
    'iter1_results10000_fin.csv',
    'iter2_results10000_fin.csv',
    'iter3_1_bvm1_corr_results10000_fin.csv',
    'iter4_1_bvm1_corr_results10000_fin.csv'
]
data_columns = {
    'Median_CEP': 'Median CEP',
    'Median_Error': 'Median Error',
    'Num_Steps': 'Number of Steps',
    'Distance_Moved': 'Distance Moved'
}
colors = ['red', 'blue', 'green', 'purple']  # Different colors for each dataset
labels = ['Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4']  # Legend labels

# Setup a 2x2 subplot grid, figure size is set to fit 3.5 inches by 3 inches
fig, axes = plt.subplots(2, 2, figsize=(3.5, 3), dpi=300)  # Increase DPI for better resolution in small plots
axes = axes.flatten()

# Loop through each data type and plot on the corresponding subplot
for ax, (key, label) in zip(axes, data_columns.items()):
    for file, color, leg_label in zip(dataset_files, colors, labels):
        # Load data from each file
        data = pd.read_csv(file)
        values = data[key].values

        # Fit the normal distribution to the specified column
        mu, sigma = norm.fit(values)
        mu, sigma = round(mu), round(sigma)  # Round parameters to the nearest integer

        # Generate x values for plotting
        x = np.logspace(np.log10(max(1, np.min(values))), np.log10(np.max(values)), 1000)
        pdf_fitted = norm.pdf(x, mu, sigma)

        # Plot the fitted normal distribution for each dataset
        ax.plot(x, pdf_fitted, '-', color=color, label=f'{leg_label}: μ={mu}, σ={sigma}')

        # Set the x-axis to logarithmic scale and dynamically set its limits based on the subplot
        ax.set_xscale('log')
        if key == 'Distance_Moved':
            ax.set_xlim([np.min(values), np.max(values)])
        else:
            ax.set_xlim([1, np.max(values)])

    # Labels and title for each subplot
    ax.set_title(f'Fit of {label}')
    ax.set_xlabel(label)
    ax.set_ylabel('Density')
    # Adjust the legend positioning outside the plot area
    ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

# Adjust layout to prevent overlap, with padding to accommodate external legends
plt.tight_layout(pad=0.5, h_pad=1.0, w_pad=1.0)

# Show the plot
plt.show()
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_57884\2339551396.py:63: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout(pad=0.5, h_pad=1.0, w_pad=1.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
from scipy.stats import norm

# Set global parameters for font size to ensure readability
rcParams.update({'font.size': 8, 'axes.labelsize': 8, 'axes.titlesize': 9, 'legend.fontsize': 5, 'xtick.labelsize': 7, 'ytick.labelsize': 7})

# Define dataset files and column types
dataset_files = [
    'iter1_results10000_fin.csv',
    'iter2_results10000_fin.csv',
    'iter3_1_bvm1_corr_results10000_fin.csv',
    'iter4_1_bvm1_corr_results10000_fin.csv'
]
data_columns = {
    'Median_CEP': 'Median CEP',
    'Median_Error': 'Median Error',
    'Num_Steps': 'Number of Steps',
    'Distance_Moved': 'Distance Moved'
}
colors = ['red', 'blue', 'green', 'purple']  # Different colors for each dataset
labels = ['Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4']  # Legend labels

# Data for the table
table_data = []
table_columns = ['Parameter', 'Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4']

# Setup a 2x2 subplot grid, figure size is set to fit 3.5 inches by 3 inches
fig, axes = plt.subplots(2, 2, figsize=(3.5, 4.5), dpi=300)  # Increase DPI for better resolution in small plots
axes = axes.flatten()

# Loop through each data type and plot on the corresponding subplot
for ax, (key, label) in zip(axes, data_columns.items()):
    row = [label]
    for file, color, leg_label in zip(dataset_files, colors, labels):
        # Load data from each file
        data = pd.read_csv(file)
        values = data[key].values

        # Fit the normal distribution to the specified column
        mu, sigma = norm.fit(values)
        mu, sigma = round(mu), round(sigma)  # Round parameters to the nearest integer

        # Add data to the table row
        row.append(f'μ={mu}, σ={sigma}')

        # Generate x values for plotting
        x = np.logspace(np.log10(max(1, np.min(values))), np.log10(np.max(values)), 1000)
        pdf_fitted = norm.pdf(x, mu, sigma)

        # Plot the fitted normal distribution for each dataset
        ax.plot(x, pdf_fitted, '-', color=color)

        # Set the x-axis to logarithmic scale and dynamically set its limits based on the subplot
        ax.set_xscale('log')
        if key == 'Distance_Moved':
            ax.set_xlim([np.min(values), np.max(values)])
        else:
            ax.set_xlim([1, np.max(values)])

    # Labels and title for each subplot
    ax.set_title(f'Fit of {label}')
    ax.set_xlabel(label)
    ax.set_ylabel('Density')

    table_data.append(row)

# Adjust layout to prevent overlap
plt.tight_layout(pad=0.5, h_pad=1.0, w_pad=1.0)

# Add a table at the bottom of the plots
axes_table = plt.table(cellText=table_data, colLabels=table_columns, loc='bottom', bbox=[0, -0.6, 1, 0.5])
axes_table.auto_set_font_size(False)
axes_table.set_fontsize(7)
axes_table.scale(1, 1.5)  # Adjust scale to fit

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
from scipy.stats import norm

# Set global parameters for font size to ensure readability
rcParams.update({'font.size': 4, 'axes.labelsize': 4, 'axes.titlesize': 4, 'legend.fontsize': 4, 'xtick.labelsize': 4, 'ytick.labelsize': 4})

# Define dataset files and column types
dataset_files = [
    'iter1_results10000_fin.csv',
    'iter2_results10000_fin.csv',
    'iter3_1_bvm1_corr_results10000_fin.csv',
    'iter4_1_bvm1_corr_results10000_fin.csv'
]
data_columns = {
    'Median_CEP': 'Median CEP',
    'Median_Error': 'Median Error',
    'Num_Steps': 'Number of Steps',
    'Distance_Moved': 'Distance Moved'
}
colors = ['red', 'blue', 'green', 'purple']  # Different colors for each dataset
labels = ['Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4']  # Legend labels

# Setup a 2x2 subplot grid, figure size is set to fit 3.5 inches by 3 inches
fig, axes = plt.subplots(2, 2, figsize=(3.5, 3), dpi=200)  # Increase DPI for better resolution in small plots
axes = axes.flatten()

# This will hold the handles and labels for the legend
legend_handles = []
legend_labels = []

# Loop through each data type and plot on the corresponding subplot
for ax, (key, label) in zip(axes, data_columns.items()):
    for file, color, leg_label in zip(dataset_files, colors, labels):
        # Load data from each file
        data = pd.read_csv(file)
        values = data[key].values

        # Fit the normal distribution to the specified column
        mu, sigma = norm.fit(values)
        mu, sigma = round(mu), round(sigma)  # Round parameters to the nearest integer

        # Generate x values for plotting
        x = np.logspace(np.log10(max(1, np.min(values))), np.log10(np.max(values)), 1000)
        pdf_fitted = norm.pdf(x, mu, sigma)

        # Plot the fitted normal distribution for each dataset
        line, = ax.plot(x, pdf_fitted, '-', color=color)

        # Collect legend handles and labels just once per color/label
        if ax == axes[0] and not legend_handles:
            legend_handles.append(line)
            legend_labels.append(leg_label)

        # Set the x-axis to logarithmic scale and dynamically set its limits based on the subplot
        ax.set_xscale('log')
        if key == 'Distance_Moved':
            ax.set_xlim([np.min(values), np.max(values)])
        else:
            ax.set_xlim([1, np.max(values)])

    # Labels and title for each subplot
    #ax.set_title(f'Fit of {label}')
    ax.set_xlabel(label)
    ax.set_ylabel('Density')

    
legend_labels = ['Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4']
# Place a single legend outside the bottom of the axes
fig.legend(handles=legend_handles, labels=legend_labels, loc='upper center', bbox_to_anchor=(0.5, 0), ncol=4)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
from scipy.stats import norm

# Set global parameters for font size to ensure readability
rcParams.update({'font.size': 5, 'axes.labelsize': 5, 'axes.titlesize': 5, 'legend.fontsize': 5, 'xtick.labelsize': 5, 'ytick.labelsize': 5})

# Define dataset files and column types
dataset_files = [
    'iter1_results10000_fin.csv',
    'iter2_results10000_fin.csv',
    'iter3_1_bvm1_corr_results10000_fin.csv',
    'iter4_1_bvm1_corr_results10000_fin.csv'
]
data_columns = {
    'Median_CEP': 'Median CEP',
    'Median_Error': 'Median Error',
    'Num_Steps': 'Number of Steps',
    'Distance_Moved': 'Distance Moved'
}
colors = ['red', 'blue', 'green', 'purple']  # Different colors for each dataset
labels = ['Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4']  # Legend labels
linestyles = [':', '-.', '--', '-']  # Different linestyles for each dataset


# Setup a 2x2 subplot grid, figure size is set to fit 3.5 inches by 3 inches
fig, axes = plt.subplots(2, 2, figsize=(3.5, 3), dpi=150)  # Increase DPI for better resolution in small plots
axes = axes.flatten()

# This will hold the handles and labels for the legend
legend_handles = [None] * 4  # Pre-allocate a list for the handles

# Loop through each data type and plot on the corresponding subplot
for ax, (key, label) in zip(axes, data_columns.items()):
    for i, (file, color, leg_label) in enumerate(zip(dataset_files, colors, labels)):
        # Load data from each file
        data = pd.read_csv(file)
        values = data[key].values

        # Fit the normal distribution to the specified column
        mu, sigma = norm.fit(values)
        mu, sigma = round(mu), round(sigma)  # Round parameters to the nearest integer

        # Generate x values for plotting
        x = np.logspace(np.log10(max(1, np.min(values))), np.log10(np.max(values)), 1000)
        pdf_fitted = norm.pdf(x, mu, sigma)

        # Plot the fitted normal distribution for each dataset
        line, = ax.plot(x, pdf_fitted, linestyle=linestyles[i], color=color)

        # Collect legend handles only once per dataset color across all subplots
        if legend_handles[i] is None:
            legend_handles[i] = line

        # Set the x-axis to logarithmic scale and dynamically set its limits based on the subplot
        ax.set_xscale('log')
        if key == 'Distance_Moved':
            ax.set_xlim([np.min(values), np.max(values)])
        else:
            ax.set_xlim([1, np.max(values)])
            

        # Set formatter for y-axis
        formatter = ScalarFormatter(useMathText=True)
        formatter.set_scientific(True)
        formatter.set_powerlimits((-1, 1))  # Use scientific notation if exponent is greater than 1 or less than -1
        ax.yaxis.set_major_formatter(formatter)            

    # Labels and title for each subplot
    ax.set_xlabel(label)
    ax.set_ylabel('Density')

# Place a single legend outside the bottom of the axes
fig.legend(handles=legend_handles, labels=labels, loc='upper center', bbox_to_anchor=(0.5, 0), ncol=4)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.ticker import ScalarFormatter
from scipy.stats import norm

# Set global parameters for font size to ensure readability
rcParams.update({'font.size': 5, 'axes.labelsize': 5, 'axes.titlesize': 4, 'legend.fontsize': 5, 'xtick.labelsize': 5, 'ytick.labelsize': 5})

# Define dataset files and column types
dataset_files = [
    'iter1_results10000_fin.csv',
    'iter2_results10000_fin.csv',
    'iter3_1_bvm1_corr_results10000_fin.csv',
    'iter4_1_bvm1_corr_results10000_fin.csv'
]
data_columns = {
    'Median_CEP': 'Median CEP',
    'Median_Error': 'Median Error',
    'Num_Steps': 'Number of Steps',
    'Distance_Moved': 'Distance Moved'
}
colors = ['red', 'blue', 'green', 'purple']  # Different colors for each dataset
labels = ['Iteration 1', 'Iteration 2', 'Iteration 3', 'Iteration 4']  # Legend labels
linestyles = [':', '-.', '--', '-']  # Different linestyles for each dataset


# Setup a 2x2 subplot grid, figure size is set to fit 3.5 inches by 3 inches
fig, axes = plt.subplots(2, 2, figsize=(3.5, 3), dpi=200)  # Increase DPI for better resolution in small plots
axes = axes.flatten()

# This will hold the handles and labels for the legend
legend_handles = [None] * 4  # Pre-allocate a list for the handles


# Loop through each data type and plot on the corresponding subplot
for ax, (key, label) in zip(axes, data_columns.items()):
    for i, (file, color, leg_label) in enumerate(zip(dataset_files, colors, labels)):
        # Load data from each file
        data = pd.read_csv(file)
        values = data[key].values

        # Fit the normal distribution to the specified column
        mu, sigma = norm.fit(values)
        mu, sigma = round(mu), round(sigma)  # Round parameters to the nearest integer

        # Generate x values for plotting
        x = np.logspace(np.log10(max(1, np.min(values))), np.log10(np.max(values)), 1000)
        pdf_fitted = norm.pdf(x, mu, sigma)

        # Plot the fitted normal distribution for each dataset
        line, = ax.plot(x, pdf_fitted,  linestyle=linestyles[i], color=color, linewidth = 1)

        # Set the x-axis to logarithmic scale and dynamically set its limits based on the subplot
        if key == 'Distance_Moved':
            ax.set_xlim([np.min(values), np.max(values)])
            #val = 1

        else:
            ax.set_xlim([1, np.max(values)])
            ax.set_xscale('log')
            

        # Set formatter for y-axis
        formatter = ScalarFormatter(useMathText=True)
        formatter.set_scientific(True)
        formatter.set_powerlimits((-1, 1))  # Use scientific notation if exponent is greater than 1 or less than -1
        ax.yaxis.set_major_formatter(formatter)

    # Labels and title for each subplot
    ax.set_xlabel(label)
    ax.set_ylabel('Density')

# Place a single legend outside the bottom of the axes
fig.legend(handles=legend_handles, labels=labels, loc='upper center', bbox_to_anchor=(0.5, 0), ncol=4)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_50356\1043897542.py:76: UserWarning: Legend does not support handles for NoneType instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#controlling-the-legend-entries
#   fig.legend(handles=legend_handles, labels=labels, loc='upper center', bbox_to_anchor=(0.5, 0), ncol=4)

# %% [markdown]
# ## Compare Iteration 3 "Num2Move"
#
# Means
# * 1: Steps = 134, Distance = 7615, Reward = -1270, Error = 15
# * 2: Steps = 137, Distance = 8413, Reward = -1214, Error = 16
# * 3: Steps = 150, Distance = 8338, Reward = -1237, Error = 15
# * 4: Steps = 183, Distance = 8586, Reward = -1363, Error = 17
# * 5: Steps = 235, Distance = 8448, Reward = -1622, Error = 26
# * 6: Steps = 328, Distance = 8507, Reward = -1970, Error = 50

# %%
results_iter3_1 = pd.read_csv('iter3_1_results1000.csv')
results_iter3_1.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_c9419">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9419_level0_col0" class="col_heading level0 col0" >Num_Steps</th>
#       <th id="T_c9419_level0_col1" class="col_heading level0 col1" >Median_Error</th>
#       <th id="T_c9419_level0_col2" class="col_heading level0 col2" >Median_CEP</th>
#       <th id="T_c9419_level0_col3" class="col_heading level0 col3" >Median_X</th>
#       <th id="T_c9419_level0_col4" class="col_heading level0 col4" >Median_Y</th>
#       <th id="T_c9419_level0_col5" class="col_heading level0 col5" >MAD_X</th>
#       <th id="T_c9419_level0_col6" class="col_heading level0 col6" >MAD_Y</th>
#       <th id="T_c9419_level0_col7" class="col_heading level0 col7" >Mean_X</th>
#       <th id="T_c9419_level0_col8" class="col_heading level0 col8" >Mean_Y</th>
#       <th id="T_c9419_level0_col9" class="col_heading level0 col9" >Std_X</th>
#       <th id="T_c9419_level0_col10" class="col_heading level0 col10" >Std_Y</th>
#       <th id="T_c9419_level0_col11" class="col_heading level0 col11" >Distance_Moved</th>
#       <th id="T_c9419_level0_col12" class="col_heading level0 col12" >TotalReward</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9419_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_c9419_row0_col0" class="data row0 col0" >1000.00</td>
#       <td id="T_c9419_row0_col1" class="data row0 col1" >1000.00</td>
#       <td id="T_c9419_row0_col2" class="data row0 col2" >1000.00</td>
#       <td id="T_c9419_row0_col3" class="data row0 col3" >1000.00</td>
#       <td id="T_c9419_row0_col4" class="data row0 col4" >1000.00</td>
#       <td id="T_c9419_row0_col5" class="data row0 col5" >1000.00</td>
#       <td id="T_c9419_row0_col6" class="data row0 col6" >1000.00</td>
#       <td id="T_c9419_row0_col7" class="data row0 col7" >1000.00</td>
#       <td id="T_c9419_row0_col8" class="data row0 col8" >1000.00</td>
#       <td id="T_c9419_row0_col9" class="data row0 col9" >1000.00</td>
#       <td id="T_c9419_row0_col10" class="data row0 col10" >1000.00</td>
#       <td id="T_c9419_row0_col11" class="data row0 col11" >1000.00</td>
#       <td id="T_c9419_row0_col12" class="data row0 col12" >1000.00</td>
#     </tr>
#     <tr>
#       <th id="T_c9419_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_c9419_row1_col0" class="data row1 col0" >293.45</td>
#       <td id="T_c9419_row1_col1" class="data row1 col1" >26.96</td>
#       <td id="T_c9419_row1_col2" class="data row1 col2" >19.64</td>
#       <td id="T_c9419_row1_col3" class="data row1 col3" >352.28</td>
#       <td id="T_c9419_row1_col4" class="data row1 col4" >361.70</td>
#       <td id="T_c9419_row1_col5" class="data row1 col5" >10.11</td>
#       <td id="T_c9419_row1_col6" class="data row1 col6" >14.92</td>
#       <td id="T_c9419_row1_col7" class="data row1 col7" >328.91</td>
#       <td id="T_c9419_row1_col8" class="data row1 col8" >294.92</td>
#       <td id="T_c9419_row1_col9" class="data row1 col9" >185.71</td>
#       <td id="T_c9419_row1_col10" class="data row1 col10" >536.65</td>
#       <td id="T_c9419_row1_col11" class="data row1 col11" >8159.02</td>
#       <td id="T_c9419_row1_col12" class="data row1 col12" >1173.79</td>
#     </tr>
#     <tr>
#       <th id="T_c9419_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_c9419_row2_col0" class="data row2 col0" >324.23</td>
#       <td id="T_c9419_row2_col1" class="data row2 col1" >39.86</td>
#       <td id="T_c9419_row2_col2" class="data row2 col2" >94.38</td>
#       <td id="T_c9419_row2_col3" class="data row2 col3" >33.96</td>
#       <td id="T_c9419_row2_col4" class="data row2 col4" >225.08</td>
#       <td id="T_c9419_row2_col5" class="data row2 col5" >34.58</td>
#       <td id="T_c9419_row2_col6" class="data row2 col6" >88.16</td>
#       <td id="T_c9419_row2_col7" class="data row2 col7" >552.63</td>
#       <td id="T_c9419_row2_col8" class="data row2 col8" >2054.85</td>
#       <td id="T_c9419_row2_col9" class="data row2 col9" >2867.98</td>
#       <td id="T_c9419_row2_col10" class="data row2 col10" >10795.40</td>
#       <td id="T_c9419_row2_col11" class="data row2 col11" >2165.73</td>
#       <td id="T_c9419_row2_col12" class="data row2 col12" >1296.94</td>
#     </tr>
#     <tr>
#       <th id="T_c9419_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_c9419_row3_col0" class="data row3 col0" >1.00</td>
#       <td id="T_c9419_row3_col1" class="data row3 col1" >0.02</td>
#       <td id="T_c9419_row3_col2" class="data row3 col2" >0.04</td>
#       <td id="T_c9419_row3_col3" class="data row3 col3" >-0.77</td>
#       <td id="T_c9419_row3_col4" class="data row3 col4" >-590.96</td>
#       <td id="T_c9419_row3_col5" class="data row3 col5" >0.02</td>
#       <td id="T_c9419_row3_col6" class="data row3 col6" >0.03</td>
#       <td id="T_c9419_row3_col7" class="data row3 col7" >-16586.12</td>
#       <td id="T_c9419_row3_col8" class="data row3 col8" >-63816.39</td>
#       <td id="T_c9419_row3_col9" class="data row3 col9" >0.09</td>
#       <td id="T_c9419_row3_col10" class="data row3 col10" >0.17</td>
#       <td id="T_c9419_row3_col11" class="data row3 col11" >3058.68</td>
#       <td id="T_c9419_row3_col12" class="data row3 col12" >4.00</td>
#     </tr>
#     <tr>
#       <th id="T_c9419_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_c9419_row4_col0" class="data row4 col0" >67.00</td>
#       <td id="T_c9419_row4_col1" class="data row4 col1" >6.27</td>
#       <td id="T_c9419_row4_col2" class="data row4 col2" >1.05</td>
#       <td id="T_c9419_row4_col3" class="data row4 col3" >341.44</td>
#       <td id="T_c9419_row4_col4" class="data row4 col4" >343.68</td>
#       <td id="T_c9419_row4_col5" class="data row4 col5" >0.68</td>
#       <td id="T_c9419_row4_col6" class="data row4 col6" >0.51</td>
#       <td id="T_c9419_row4_col7" class="data row4 col7" >339.30</td>
#       <td id="T_c9419_row4_col8" class="data row4 col8" >342.22</td>
#       <td id="T_c9419_row4_col9" class="data row4 col9" >2.97</td>
#       <td id="T_c9419_row4_col10" class="data row4 col10" >2.87</td>
#       <td id="T_c9419_row4_col11" class="data row4 col11" >6883.85</td>
#       <td id="T_c9419_row4_col12" class="data row4 col12" >268.00</td>
#     </tr>
#     <tr>
#       <th id="T_c9419_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_c9419_row5_col0" class="data row5 col0" >146.50</td>
#       <td id="T_c9419_row5_col1" class="data row5 col1" >14.77</td>
#       <td id="T_c9419_row5_col2" class="data row5 col2" >1.47</td>
#       <td id="T_c9419_row5_col3" class="data row5 col3" >351.09</td>
#       <td id="T_c9419_row5_col4" class="data row5 col4" >351.25</td>
#       <td id="T_c9419_row5_col5" class="data row5 col5" >1.02</td>
#       <td id="T_c9419_row5_col6" class="data row5 col6" >0.87</td>
#       <td id="T_c9419_row5_col7" class="data row5 col7" >351.07</td>
#       <td id="T_c9419_row5_col8" class="data row5 col8" >351.09</td>
#       <td id="T_c9419_row5_col9" class="data row5 col9" >7.31</td>
#       <td id="T_c9419_row5_col10" class="data row5 col10" >7.19</td>
#       <td id="T_c9419_row5_col11" class="data row5 col11" >8077.19</td>
#       <td id="T_c9419_row5_col12" class="data row5 col12" >586.00</td>
#     </tr>
#     <tr>
#       <th id="T_c9419_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_c9419_row6_col0" class="data row6 col0" >380.50</td>
#       <td id="T_c9419_row6_col1" class="data row6 col1" >30.10</td>
#       <td id="T_c9419_row6_col2" class="data row6 col2" >1.84</td>
#       <td id="T_c9419_row6_col3" class="data row6 col3" >362.23</td>
#       <td id="T_c9419_row6_col4" class="data row6 col4" >358.95</td>
#       <td id="T_c9419_row6_col5" class="data row6 col5" >1.47</td>
#       <td id="T_c9419_row6_col6" class="data row6 col6" >1.33</td>
#       <td id="T_c9419_row6_col7" class="data row6 col7" >363.43</td>
#       <td id="T_c9419_row6_col8" class="data row6 col8" >360.73</td>
#       <td id="T_c9419_row6_col9" class="data row6 col9" >26.26</td>
#       <td id="T_c9419_row6_col10"

# %%
results_iter3_2 = pd.read_csv('iter3_2_results1000.csv')
results_iter3_2.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_5fc54">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5fc54_level0_col0" class="col_heading level0 col0" >Num_Steps</th>
#       <th id="T_5fc54_level0_col1" class="col_heading level0 col1" >Median_Error</th>
#       <th id="T_5fc54_level0_col2" class="col_heading level0 col2" >Median_CEP</th>
#       <th id="T_5fc54_level0_col3" class="col_heading level0 col3" >Median_X</th>
#       <th id="T_5fc54_level0_col4" class="col_heading level0 col4" >Median_Y</th>
#       <th id="T_5fc54_level0_col5" class="col_heading level0 col5" >MAD_X</th>
#       <th id="T_5fc54_level0_col6" class="col_heading level0 col6" >MAD_Y</th>
#       <th id="T_5fc54_level0_col7" class="col_heading level0 col7" >Mean_X</th>
#       <th id="T_5fc54_level0_col8" class="col_heading level0 col8" >Mean_Y</th>
#       <th id="T_5fc54_level0_col9" class="col_heading level0 col9" >Std_X</th>
#       <th id="T_5fc54_level0_col10" class="col_heading level0 col10" >Std_Y</th>
#       <th id="T_5fc54_level0_col11" class="col_heading level0 col11" >Distance_Moved</th>
#       <th id="T_5fc54_level0_col12" class="col_heading level0 col12" >TotalReward</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fc54_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_5fc54_row0_col0" class="data row0 col0" >1000.00</td>
#       <td id="T_5fc54_row0_col1" class="data row0 col1" >1000.00</td>
#       <td id="T_5fc54_row0_col2" class="data row0 col2" >1000.00</td>
#       <td id="T_5fc54_row0_col3" class="data row0 col3" >1000.00</td>
#       <td id="T_5fc54_row0_col4" class="data row0 col4" >1000.00</td>
#       <td id="T_5fc54_row0_col5" class="data row0 col5" >1000.00</td>
#       <td id="T_5fc54_row0_col6" class="data row0 col6" >1000.00</td>
#       <td id="T_5fc54_row0_col7" class="data row0 col7" >1000.00</td>
#       <td id="T_5fc54_row0_col8" class="data row0 col8" >1000.00</td>
#       <td id="T_5fc54_row0_col9" class="data row0 col9" >1000.00</td>
#       <td id="T_5fc54_row0_col10" class="data row0 col10" >1000.00</td>
#       <td id="T_5fc54_row0_col11" class="data row0 col11" >1000.00</td>
#       <td id="T_5fc54_row0_col12" class="data row0 col12" >1000.00</td>
#     </tr>
#     <tr>
#       <th id="T_5fc54_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_5fc54_row1_col0" class="data row1 col0" >235.22</td>
#       <td id="T_5fc54_row1_col1" class="data row1 col1" >21.18</td>
#       <td id="T_5fc54_row1_col2" class="data row1 col2" >7.06</td>
#       <td id="T_5fc54_row1_col3" class="data row1 col3" >351.87</td>
#       <td id="T_5fc54_row1_col4" class="data row1 col4" >351.55</td>
#       <td id="T_5fc54_row1_col5" class="data row1 col5" >4.33</td>
#       <td id="T_5fc54_row1_col6" class="data row1 col6" >4.93</td>
#       <td id="T_5fc54_row1_col7" class="data row1 col7" >353.43</td>
#       <td id="T_5fc54_row1_col8" class="data row1 col8" >352.37</td>
#       <td id="T_5fc54_row1_col9" class="data row1 col9" >67.35</td>
#       <td id="T_5fc54_row1_col10" class="data row1 col10" >68.18</td>
#       <td id="T_5fc54_row1_col11" class="data row1 col11" >8656.85</td>
#       <td id="T_5fc54_row1_col12" class="data row1 col12" >470.44</td>
#     </tr>
#     <tr>
#       <th id="T_5fc54_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_5fc54_row2_col0" class="data row2 col0" >264.00</td>
#       <td id="T_5fc54_row2_col1" class="data row2 col1" >25.90</td>
#       <td id="T_5fc54_row2_col2" class="data row2 col2" >40.30</td>
#       <td id="T_5fc54_row2_col3" class="data row2 col3" >23.59</td>
#       <td id="T_5fc54_row2_col4" class="data row2 col4" >24.33</td>
#       <td id="T_5fc54_row2_col5" class="data row2 col5" >19.19</td>
#       <td id="T_5fc54_row2_col6" class="data row2 col6" >35.53</td>
#       <td id="T_5fc54_row2_col7" class="data row2 col7" >97.96</td>
#       <td id="T_5fc54_row2_col8" class="data row2 col8" >115.37</td>
#       <td id="T_5fc54_row2_col9" class="data row2 col9" >405.15</td>
#       <td id="T_5fc54_row2_col10" class="data row2 col10" >438.94</td>
#       <td id="T_5fc54_row2_col11" class="data row2 col11" >1891.21</td>
#       <td id="T_5fc54_row2_col12" class="data row2 col12" >528.00</td>
#     </tr>
#     <tr>
#       <th id="T_5fc54_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_5fc54_row3_col0" class="data row3 col0" >1.00</td>
#       <td id="T_5fc54_row3_col1" class="data row3 col1" >0.03</td>
#       <td id="T_5fc54_row3_col2" class="data row3 col2" >0.06</td>
#       <td id="T_5fc54_row3_col3" class="data row3 col3" >167.57</td>
#       <td id="T_5fc54_row3_col4" class="data row3 col4" >206.71</td>
#       <td id="T_5fc54_row3_col5" class="data row3 col5" >0.03</td>
#       <td id="T_5fc54_row3_col6" class="data row3 col6" >0.04</td>
#       <td id="T_5fc54_row3_col7" class="data row3 col7" >-867.78</td>
#       <td id="T_5fc54_row3_col8" class="data row3 col8" >-810.30</td>
#       <td id="T_5fc54_row3_col9" class="data row3 col9" >0.14</td>
#       <td id="T_5fc54_row3_col10" class="data row3 col10" >0.12</td>
#       <td id="T_5fc54_row3_col11" class="data row3 col11" >3315.31</td>
#       <td id="T_5fc54_row3_col12" class="data row3 col12" >2.00</td>
#     </tr>
#     <tr>
#       <th id="T_5fc54_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_5fc54_row4_col0" class="data row4 col0" >60.00</td>
#       <td id="T_5fc54_row4_col1" class="data row4 col1" >6.10</td>
#       <td id="T_5fc54_row4_col2" class="data row4 col2" >1.01</td>
#       <td id="T_5fc54_row4_col3" class="data row4 col3" >341.35</td>
#       <td id="T_5fc54_row4_col4" class="data row4 col4" >342.08</td>
#       <td id="T_5fc54_row4_col5" class="data row4 col5" >0.65</td>
#       <td id="T_5fc54_row4_col6" class="data row4 col6" >0.52</td>
#       <td id="T_5fc54_row4_col7" class="data row4 col7" >339.91</td>
#       <td id="T_5fc54_row4_col8" class="data row4 col8" >341.44</td>
#       <td id="T_5fc54_row4_col9" class="data row4 col9" >3.00</td>
#       <td id="T_5fc54_row4_col10" class="data row4 col10" >2.75</td>
#       <td id="T_5fc54_row4_col11" class="data row4 col11" >7342.91</td>
#       <td id="T_5fc54_row4_col12" class="data row4 col12" >120.00</td>
#     </tr>
#     <tr>
#       <th id="T_5fc54_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_5fc54_row5_col0" class="data row5 col0" >129.50</td>
#       <td id="T_5fc54_row5_col1" class="data row5 col1" >13.50</td>
#       <td id="T_5fc54_row5_col2" class="data row5 col2" >1.45</td>
#       <td id="T_5fc54_row5_col3" class="data row5 col3" >351.44</td>
#       <td id="T_5fc54_row5_col4" class="data row5 col4" >350.19</td>
#       <td id="T_5fc54_row5_col5" class="data row5 col5" >0.98</td>
#       <td id="T_5fc54_row5_col6" class="data row5 col6" >0.85</td>
#       <td id="T_5fc54_row5_col7" class="data row5 col7" >351.71</td>
#       <td id="T_5fc54_row5_col8" class="data row5 col8" >350.41</td>
#       <td id="T_5fc54_row5_col9" class="data row5 col9" >6.46</td>
#       <td id="T_5fc54_row5_col10" class="data row5 col10" >6.08</td>
#       <td id="T_5fc54_row5_col11" class="data row5 col11" >8658.22</td>
#       <td id="T_5fc54_row5_col12" class="data row5 col12" >259.00</td>
#     </tr>
#     <tr>
#       <th id="T_5fc54_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_5fc54_row6_col0" class="data row6 col0" >289.00</td>
#       <td id="T_5fc54_row6_col1" class="data row6 col1" >26.71</td>
#       <td id="T_5fc54_row6_col2" class="data row6 col2" >1.77</td>
#       <td id="T_5fc54_row6_col3" class="data row6 col3" >360.57</td>
#       <td id="T_5fc54_row6_col4" class="data row6 col4" >357.94</td>
#       <td id="T_5fc54_row6_col5" class="data row6 col5" >1.34</td>
#       <td id="T_5fc54_row6_col6" class="data row6 col6" >1.22</td>
#       <td id="T_5fc54_row6_col7" class="data row6 col7" >361.24</td>
#       <td id="T_5fc54_row6_col8" class="data row6 col8" >359.08</td>
#       <td id="T_5fc54_row6_col9" class="data row6 col9" >17.84</td>
#       <td id="T_5fc54_row6_col10" class="data row6

# %%
results_iter3_3 = pd.read_csv('iter3_3_results1000.csv')
results_iter3_3.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_20c54">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20c54_level0_col0" class="col_heading level0 col0" >Num_Steps</th>
#       <th id="T_20c54_level0_col1" class="col_heading level0 col1" >Median_Error</th>
#       <th id="T_20c54_level0_col2" class="col_heading level0 col2" >Median_CEP</th>
#       <th id="T_20c54_level0_col3" class="col_heading level0 col3" >Median_X</th>
#       <th id="T_20c54_level0_col4" class="col_heading level0 col4" >Median_Y</th>
#       <th id="T_20c54_level0_col5" class="col_heading level0 col5" >MAD_X</th>
#       <th id="T_20c54_level0_col6" class="col_heading level0 col6" >MAD_Y</th>
#       <th id="T_20c54_level0_col7" class="col_heading level0 col7" >Mean_X</th>
#       <th id="T_20c54_level0_col8" class="col_heading level0 col8" >Mean_Y</th>
#       <th id="T_20c54_level0_col9" class="col_heading level0 col9" >Std_X</th>
#       <th id="T_20c54_level0_col10" class="col_heading level0 col10" >Std_Y</th>
#       <th id="T_20c54_level0_col11" class="col_heading level0 col11" >Distance_Moved</th>
#       <th id="T_20c54_level0_col12" class="col_heading level0 col12" >TotalReward</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20c54_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_20c54_row0_col0" class="data row0 col0" >1000.00</td>
#       <td id="T_20c54_row0_col1" class="data row0 col1" >1000.00</td>
#       <td id="T_20c54_row0_col2" class="data row0 col2" >1000.00</td>
#       <td id="T_20c54_row0_col3" class="data row0 col3" >1000.00</td>
#       <td id="T_20c54_row0_col4" class="data row0 col4" >1000.00</td>
#       <td id="T_20c54_row0_col5" class="data row0 col5" >1000.00</td>
#       <td id="T_20c54_row0_col6" class="data row0 col6" >1000.00</td>
#       <td id="T_20c54_row0_col7" class="data row0 col7" >1000.00</td>
#       <td id="T_20c54_row0_col8" class="data row0 col8" >1000.00</td>
#       <td id="T_20c54_row0_col9" class="data row0 col9" >1000.00</td>
#       <td id="T_20c54_row0_col10" class="data row0 col10" >1000.00</td>
#       <td id="T_20c54_row0_col11" class="data row0 col11" >1000.00</td>
#       <td id="T_20c54_row0_col12" class="data row0 col12" >1000.00</td>
#     </tr>
#     <tr>
#       <th id="T_20c54_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_20c54_row1_col0" class="data row1 col0" >222.45</td>
#       <td id="T_20c54_row1_col1" class="data row1 col1" >20.13</td>
#       <td id="T_20c54_row1_col2" class="data row1 col2" >5.04</td>
#       <td id="T_20c54_row1_col3" class="data row1 col3" >351.46</td>
#       <td id="T_20c54_row1_col4" class="data row1 col4" >351.11</td>
#       <td id="T_20c54_row1_col5" class="data row1 col5" >3.75</td>
#       <td id="T_20c54_row1_col6" class="data row1 col6" >2.92</td>
#       <td id="T_20c54_row1_col7" class="data row1 col7" >348.51</td>
#       <td id="T_20c54_row1_col8" class="data row1 col8" >347.18</td>
#       <td id="T_20c54_row1_col9" class="data row1 col9" >59.88</td>
#       <td id="T_20c54_row1_col10" class="data row1 col10" >66.01</td>
#       <td id="T_20c54_row1_col11" class="data row1 col11" >7990.65</td>
#       <td id="T_20c54_row1_col12" class="data row1 col12" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_20c54_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_20c54_row2_col0" class="data row2 col0" >231.03</td>
#       <td id="T_20c54_row2_col1" class="data row2 col1" >37.64</td>
#       <td id="T_20c54_row2_col2" class="data row2 col2" >33.31</td>
#       <td id="T_20c54_row2_col3" class="data row2 col3" >30.15</td>
#       <td id="T_20c54_row2_col4" class="data row2 col4" >39.19</td>
#       <td id="T_20c54_row2_col5" class="data row2 col5" >22.96</td>
#       <td id="T_20c54_row2_col6" class="data row2 col6" >24.19</td>
level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_20c54_row6_col0" class="data row6 col0" >285.25</td>
#       <td id="T_20c54_row6_col1" class="data row6 col1" >22.33</td>
#       <td id="T_20c54_row6_col2" class="data row6 col2" >1.77</td>
#       <td id="T_20c54_row6_col3" class="data row6 col3" >358.54</td>
#       <td id="T_20c54_row6_col4" class="data row6 col4" >356.74</td>
#       <td id="T_20c54_row6_col5" class="data row6 col5" >1.34</td>
#       <td id="T_20c54_row6_col6" class="data row6 col6" >1.19</td>
#       <td id="T_20c54_row6_col7" class="data row6 col7" >359.75</td>
#       <td id="T_20c54_row6_col8" class="data row6 col8" >357.24</td>
#       <td id="T_20c54_row6_col9" class="data row6 col9" >13.84</td>
#       <td id="T_20c54_row6_col10" class="data row6 col10

# %%
results_iter3_4 = pd.read_csv('iter3_4_results1000.csv')
results_iter3_4.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_9eb59">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9eb59_level0_col0" class="col_heading level0 col0" >Num_Steps</th>
#       <th id="T_9eb59_level0_col1" class="col_heading level0 col1" >Median_Error</th>
#       <th id="T_9eb59_level0_col2" class="col_heading level0 col2" >Median_CEP</th>
#       <th id="T_9eb59_level0_col3" class="col_heading level0 col3" >Median_X</th>
#       <th id="T_9eb59_level0_col4" class="col_heading level0 col4" >Median_Y</th>
#       <th id="T_9eb59_level0_col5" class="col_heading level0 col5" >MAD_X</th>
#       <th id="T_9eb59_level0_col6" class="col_heading level0 col6" >MAD_Y</th>
#       <th id="T_9eb59_level0_col7" class="col_heading level0 col7" >Mean_X</th>
#       <th id="T_9eb59_level0_col8" class="col_heading level0 col8" >Mean_Y</th>
#       <th id="T_9eb59_level0_col9" class="col_heading level0 col9" >Std_X</th>
#       <th id="T_9eb59_level0_col10" class="col_heading level0 col10" >Std_Y</th>
#       <th id="T_9eb59_level0_col11" class="col_heading level0 col11" >Distance_Moved</th>
#       <th id="T_9eb59_level0_col12" class="col_heading level0 col12" >TotalReward</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9eb59_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_9eb59_row0_col0" class="data row0 col0" >1000.00</td>
#       <td id="T_9eb59_row0_col1" class="data row0 col1" >1000.00</td>
#       <td id="T_9eb59_row0_col2" class="data row0 col2" >1000.00</td>
#       <td id="T_9eb59_row0_col3" class="data row0 col3" >1000.00</td>
#       <td id="T_9eb59_row0_col4" class="data row0 col4" >1000.00</td>
#       <td id="T_9eb59_row0_col5" class="data row0 col5" >1000.00</td>
#       <td id="T_9eb59_row0_col6" class="data row0 col6" >1000.00</td>
#       <td id="T_9eb59_row0_col7" class="data row0 col7" >1000.00</td>
#       <td id="T_9eb59_row0_col8" class="data row0 col8" >1000.00</td>
#       <td id="T_9eb59_row0_col9" class="data row0 col9" >1000.00</td>
#       <td id="T_9eb59_row0_col10" class="data row0 col10" >1000.00</td>
#       <td id="T_9eb59_row0_col11" class="data row0 col11" >1000.00</td>
#       <td id="T_9eb59_row0_col12" class="data row0 col12" >1000.00</td>
#     </tr>
#     <tr>
#       <th id="T_9eb59_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_9eb59_row1_col0" class="data row1 col0" >211.37</td>
#       <td id="T_9eb59_row1_col1" class="data row1 col1" >20.69</td>
#       <td id="T_9eb59_row1_col2" class="data row1 col2" >4.13</td>
#       <td id="T_9eb59_row1_col3" class="data row1 col3" >351.47</td>
#       <td id="T_9eb59_row1_col4" class="data row1 col4" >349.97</td>
#       <td id="T_9eb59_row1_col5" class="data row1 col5" >2.94</td>
#       <td id="T_9eb59_row1_col6" class="data row1 col6" >2.55</td>
#       <td id="T_9eb59_row1_col7" class="data row1 col7" >351.82</td>
#       <td id="T_9eb59_row1_col8" class="data row1 col8" >349.54</td>
#       <td id="T_9eb59_row1_col9" class="data row1 col9" >44.83</td>
#       <td id="T_9eb59_row1_col10" class="data row1 col10" >41.35</td>
#       <td id="T_9eb59_row1_col11" class="data row1 col11" >7687.10</td>
#       <td id="T_9eb59_row1_col12" class="data row1 col12" >-422.74</td>
#     </tr>
#     <tr>
#       <th id="T_9eb59_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_9eb59_row2_col0" class="data row2 col0" >218.94</td>
#       <td id="T_9eb59_row2_col1" class="data row2 col1" >26.97</td>
#       <td id="T_9eb59_row2_col2" class="data row2 col2" >25.66</td>
#       <td id="T_9eb59_row2_col3" class="data row2 col3" >23.99</td>
#       <td id="T_9eb59_row2_col4" class="data row2 col4" >18.37</td>
#       <td id="T_9eb59_row2_col5" class="data row2 col5" >18.65</td>
#       <td id="T_9eb59_row2_col6" class="data row2 col6" >17.68</td>
#       <td id="T_9eb59_row2_col7" class="data row2 col7" >46.79</td>
#       <td id="T_9eb59_row2_col8" class="data row2 col8" >59.88</td>
#       <td id="T_9eb59_row2_col9" class="data row2 col9" >243.90</td>
#       <td id="T_9eb59_row2_col10" class="data row2 col10" >343.61</td>
#       <td id="T_9eb59_row2_col11" class="data row2 col11" >1896.56</td>
#       <td id="T_9eb59_row2_col12" class="data row2 col12" >437.88</td>
#     </tr>
#     <tr>
#       <th id="T_9eb59_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_9eb59_row3_col0" class="data row3 col0" >1.00</td>
#       <td id="T_9eb59_row3_col1" class="data row3 col1" >0.03</td>
#       <td id="T_9eb59_row3_col2" class="data row3 col2" >0.03</td>
#       <td id="T_9eb59_row3_col3" class="data row3 col3" >165.84</td>
#       <td id="T_9eb59_row3_col4" class="data row3 col4" >201.07</td>
#       <td id="T_9eb59_row3_col5" class="data row3 col5" >0.01</td>
#       <td id="T_9eb59_row3_col6" class="data row3 col6" >0.03</td>
#       <td id="T_9eb59_row3_col7" class="data row3 col7" >-392.71</td>
#       <td id="T_9eb59_row3_col8" class="data row3 col8" >-1225.68</td>
#       <td id="T_9eb59_row3_col9" class="data row3 col9" >0.07</td>
#       <td id="T_9eb59_row3_col10" class="data row3 col10" >0.07</td>
#       <td id="T_9eb59_row3_col11" class="data row3 col11" >3461.91</td>
#       <td id="T_9eb59_row3_col12" class="data row3 col12" >-2000.00</td>
#     </tr>
#     <tr>
#       <th id="T_9eb59_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_9eb59_row4_col0" class="data row4 col0" >75.00</td>
#       <td id="T_9eb59_row4_col1" class="data row4 col1" >5.71</td>
#       <td id="T_9eb59_row4_col2" class="data row4 col2" >0.99</td>
#       <td id="T_9eb59_row4_col3" class="data row4 col3" >341.37</td>
#       <td id="T_9eb59_row4_col4" class="data row4 col4" >342.24</td>
#       <td id="T_9eb59_row4_col5" class="data row4 col5" >0.61</td>
#       <td id="T_9eb59_row4_col6" class="data row4 col6" >0.49</td>
#       <td id="T_9eb59_row4_col7" class="data row4 col7" >340.87</td>
#       <td id="T_9eb59_row4_col8" class="data row4 col8" >341.47</td>
#       <td id="T_9eb59_row4_col9" class="data row4 col9" >2.94</td>
#       <td id="T_9eb59_row4_col10" class="data row4 col10" >2.64</td>
#       <td id="T_9eb59_row4_col11" class="data row4 col11" >6286.44</td>
#       <td id="T_9eb59_row4_col12" class="data row4 col12" >-526.00</td>
#     </tr>
#     <tr>
#       <th id="T_9eb59_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_9eb59_row5_col0" class="data row5 col0" >138.50</td>
#       <td id="T_9eb59_row5_col1" class="data row5 col1" >13.15</td>
#       <td id="T_9eb59_row5_col2" class="data row5 col2" >1.40</td>
#       <td id="T_9eb59_row5_col3" class="data row5 col3" >350.78</td>
#       <td id="T_9eb59_row5_col4" class="data row5 col4" >349.32</td>
#       <td id="T_9eb59_row5_col5" class="data row5 col5" >0.98</td>
#       <td id="T_9eb59_row5_col6" class="data row5 col6" >0.82</td>
#       <td id="T_9eb59_row5_col7" class="data row5 col7" >350.86</td>
#       <td id="T_9eb59_row5_col8" class="data row5 col8" >349.64</td>
#       <td id="T_9eb59_row5_col9" class="data row5 col9" >6.31</td>
#       <td id="T_9eb59_row5_col10" class="data row5 col10" >5.57</td>
#       <td id="T_9eb59_row5_col11" class="data row5 col11" >7591.54</td>
#       <td id="T_9eb59_row5_col12" class="data row5 col12" >-277.00</td>
#     </tr>
#     <tr>
#       <th id="T_9eb59_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_9eb59_row6_col0" class="data row6 col0" >263.00</td>
#       <td id="T_9eb59_row6_col1" class="data row6 col1" >24.76</td>
#       <td id="T_9eb59_row6_col2" class="data row6 col2" >1.75</td>
#       <td id="T_9eb59_row6_col3" class="data row6 col3" >359.65</td>
#       <td id="T_9eb59_row6_col4" class="data row6 col4" >357.39</td>
#       <td id="T_9eb59_row6_col5" class="data row6 col5" >1.32</td>
#       <td id="T_9eb59_row6_col6" class="data row6 col6" >1.17</td>
#       <td id="T_9eb59_row6_col7" class="data row6 col7" >361.63</td>
#       <td id="T_9eb59_row6_col8" class="data row6 col8" >359.07</td>
#       <td id="T_9eb59_row6_col9" class="data row6 col9" >17.03</td>
#       <td id="T_9eb59_row6_col10" class="dat

# %%
results_iter3_5 = pd.read_csv('iter3_5_results1000.csv')
results_iter3_5.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T
td>
#     </tr>
#     <tr>
#       <th id="T_498e5_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_498e5_row4_col0" class="data row4 col0" >72.00</td>
#       <td id="T_498e5_row4_col1" class="data row4 col1" >5.29</td>
#       <td id="T_498e5_row4_col2" class="data row4 col2" >1.04</td>
#       <td id="T_498e5_row4_col3" class="data row4 col3" >341.45</td>
#       <td id="T_498e5_row4_col4" class="data row4 col4" >342.25</td>
#       <td id="T_498e5_row4_col5" class="data row4 col5" >0.62</td>
#       <td id="T_498e5_row4_col6" class="data row4 col6" >0.52</td>
#       <td id="T_498e5_row4_col7" class="data row4 col7" >340.75</td>
#       <td id="T_498e5_row4_col8" class="data row4 col8" >341.46</td>
#       <td id="T_498e5_row4_col9" class="data row4 col9" >3.06</td>
#       <td id="T_498e5_row4_col10" class="data row4 col10" >2.50</td>
#       <td id="T_498e5_row4_col11" class="data row4 col11" >6860.10</td>
#       <td id="T_498e5_row4_col12" class="data row4 col12" >-1188.00</td>
#     </tr>
#     <tr>
#       <th id="T_498e5_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_498e5_row5_col0" class="data row5 col0" >158.50</td>
#       <td id="T_498e5_row5_col1" class="data row5 col1" >13.04</td>
#       <td id="T_498e5_row5_col2" class="data row5 col2" >1.48</td>
#       <td id="T_498e5_row5_col3" class="data row5 col3" >350.46</td>
#       <td id="T_498e5_row5_col4" class="data row5 col4" >349.38</td>
#       <td id="T_498e5_row5_col5" class="data row5 col5" >0.99</td>
#       <td id="T_498e5_row5_col6" class="data row5 col6" >0.88</td>
#       <td id="T_498e5_row5_col7" class="data row5 col7" >350.33</td>
#       <td id="T_498e5_row5_col8" class="data row5 col8" >350.00</td>
#       <td id="T_498e5_row5_col9" class="data row5 col9" >6.54</td>
#       <td id="T_498e5_row5_col10" class="data row5 col10" >5.67</td>
#       <td id="T_498e5_row5_col11" class="data row5 col11" >8333.30</td>
#       <td id="T_498e5_row5_col12" class="data row5 col12" >-634.00</td>
#     </tr>
#     <tr>
#       <th id="T_498e5_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_498e5_row6_col0" class="data row6 col0" >297.00</td>
#       <td id="T_498e5_row6_col1" class="data row6 col1" >27.41</td>
#       <td id="T_498e5_row6_col2" class="data row6 col2" >1.79</td>
#       <td id="T_498e5_row6_col3" class="data row6 col3" >359.74</td>
#       <td id="T_498e5_row6_col4" class="data row6 col4" >357.46</td>
#       <td id="T_498e5_row6_col5" class="data row6 col5" >1.38</td>
#       <td id="T_498e5_row6_col6" class="data row6 col6" >1.28</td>
#       <td id="T_498e5_row6_col7" class="data row6 col7" >360.68</td>
#       <td id="T_498e5_row6_col8" class="data row6 col8" >358.70</td>
#       <td id="T_498e5_row6_col9" class="data row6 col9" >19.26</td>
#       <td id="T_498e5_row6_col

# %%
results_iter3_6 = pd.read_csv('iter3_6_results1000.csv')
results_iter3_6.describe().style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_b9f80">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9f80_level0_col0" class="col_heading level0 col0" >Num_Steps</th>
#       <th id="T_b9f80_level0_col1" class="col_heading level0 col1" >Median_Error</th>
#       <th id="T_b9f80_level0_col2" class="col_heading level0 col2" >Median_CEP</th>
#       <th id="T_b9f80_level0_col3" class="col_heading level0 col3" >Median_X</th>
#       <th id="T_b9f80_level0_col4" class="col_heading level0 col4" >Median_Y</th>
#       <th id="T_b9f80_level0_col5" class="col_heading level0 col5" >MAD_X</th>
#       <th id="T_b9f80_level0_col6" class="col_heading level0 col6" >MAD_Y</th>
#       <th id="T_b9f80_level0_col7" class="col_heading level0 col7" >Mean_X</th>
#       <th id="T_b9f80_level0_col8" class="col_heading level0 col8" >Mean_Y</th>
#       <th id="T_b9f80_level0_col9" class="col_heading level0 col9" >Std_X</th>
#       <th id="T_b9f80_level0_col10" class="col_heading level0 col10" >Std_Y</th>
#       <th id="T_b9f80_level0_col11" class="col_heading level0 col11" >Distance_Moved</th>
#       <th id="T_b9f80_level0_col12" class="col_heading level0 col12" >TotalReward</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9f80_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_b9f80_row0_col0" class="data row0 col0" >1000.00</td>
#       <td id="T_b9f80_row0_col1" class="data row0 col1" >1000.00</td>
#       <td id="T_b9f80_row0_col2" class="data row0 col2" >1000.00</td>
#       <td id="T_b9f80_row0_col3" class="data row0 col3" >1000.00</td>
#       <td id="T_b9f80_row0_col4" class="data row0 col4" >1000.00</td>
#       <td id="T_b9f80_row0_col5" class="data row0 col5" >1000.00</td>
#       <td id="T_b9f80_row0_col6" class="data row0 col6" >1000.00</td>
#       <td id="T_b9f80_row0_col7" class="data row0 col7" >1000.00</td>
#       <td id="T_b9f80_row0_col8" class="data row0 col8" >1000.00</td>
#       <td id="T_b9f80_row0_col9" class="data row0 col9" >1000.00</td>
#       <td id="T_b9f80_row0_col10" class="data row0 col10" >1000.00</td>
#       <td id="T_b9f80_row0_col11" class="data row0 col11" >1000.00</td>
#       <td id="T_b9f80_row0_col12" class="data row0 col12" >1000.00</td>
#     </tr>
#     <tr>
#       <th id="T_b9f80_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_b9f80_row1_col0" class="data row1 col0" >314.69</td>
#       <td id="T_b9f80_row1_col1" class="data row1 col1" >50.80</td>
#       <td id="T_b9f80_row1_col2" class="data row1 col2" >54.56</td>
#       <td id="T_b9f80_row1_col3" class="data row1 col3" >359.59</td>
#       <td id="T_b9f80_row1_col4" class="data row1 col4" >311.44</td>
#       <td id="T_b9f80_row1_col5" class="data row1 col5" >24.51</td>
#       <td id="T_b9f80_row1_col6" class="data row1 col6" >44.11</td>
#       <td id="T_b9f80_row1_col7" class="data row1 col7" >381.38</td>
#       <td id="T_b9f80_row1_col8" class="data row1 col8" >187.68</td>
#       <td id="T_b9f80_row1_col9" class="data row1 col9" >492.37</td>
#       <td id="T_b9f80_row1_col10" class="data row1 col10" >1168.81</td>
#       <td id="T_b9f80_row1_col11" class="data row1 col11" >8750.77</td>
#       <td id="T_b9f80_row1_col12" class="data row1 col12" >-1888.15</td>
#     </tr>
#     <tr>
#       <th id="T_b9f80_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_b9f80_row2_col0" class="data row2 col0" >325.69</td>
#       <td id="T_b9f80_row2_col1" class="data row2 col1" >132.02</td>
#       <td id="T_b9f80_row2_col2" class="data row2 col2" >214.90</td>
#       <td id="T_b9f80_row2_col3" class="data row2 col3" >99.57</td>
#       <td id="T_b9f80_row2_col4" class="data row2 col4" >259.54</td>
#       <td id="T_b9f80_row2_col5" class="data row2 col5" >101.18</td>
#       <td id="T_b9f80_row2_col6" class="data row2 col6" >190.72</td>
#       <td id="T_b9f80_row2_col7" class="data row2 col7" >1268.29</td>
#       <td id="T_b9f80_row2_col8" class="data row2 col8" >4111.90</td>
#       <td id="T_b9f80_row2_col9" class="data row2 col9" >7016.16</td>
#       <td id="T_b9f80_row2_col10" class="data row2 col10" >23020.80</td>
#       <td id="T_b9f80_row2_col11" class="data row2 col11" >3275.87</td>
#       <td id="T_b9f80_row2_col12" class="data row2 col12" >1954.17</td>
#     </tr>
#     <tr>
#       <th id="T_b9f80_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_b9f80_row3_col0" class="data row3 col0" >1.00</td>
#       <td id="T_b9f80_row3_col1" class="data row3 col1" >0.01</td>
#       <td id="T_b9f80_row3_col2" class="data row3 col2" >0.07</td>
#       <td id="T_b9f80_row3_col3" class="data row3 col3" >-60.31</td>
#       <td id="T_b9f80_row3_col4" class="data row3 col4" >-3598.06</td>
#       <td id="T_b9f80_row3_col5" class="data row3 col5" >0.02</td>
#       <td id="T_b9f80_row3_col6" class="data row3 col6" >0.02</td>
#       <td id="T_b9f80_row3_col7" class="data row3 col7" >-4699.26</td>
#       <td id="T_b9f80_row3_col8" class="data row3 col8" >-128408.44</td>
#       <td id="T_b9f80_row3_col9" class="data row3 col9" >0.17</td>
#       <td id="T_b9f80_row3_col10" class="data row3 col10" >0.18</td>
#       <td id="T_b9f80_row3_col11" class="data row3 col11" >2889.37</td>
#       <td id="T_b9f80_row3_col12" class="data row3 col12" >-6000.00</td>
#     </tr>
#     <tr>
#       <th id="T_b9f80_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_b9f80_row4_col0" class="data row4 col0" >84.00</td>
#       <td id="T_b9f80_row4_col1" class="data row4 col1" >6.24</td>
#       <td id="T_b9f80_row4_col2" class="data row4 col2" >1.05</td>
#       <td id="T_b9f80_row4_col3" class="data row4 col3" >340.88</td>
#       <td id="T_b9f80_row4_col4" class="data row4 col4" >340.30</td>
#       <td id="T_b9f80_row4_col5" class="data row4 col5" >0.64</td>
#       <td id="T_b9f80_row4_col6" class="data row4 col6" >0.55</td>
#       <td id="T_b9f80_row4_col7" class="data row4 col7" >339.34</td>
#       <td id="T_b9f80_row4_col8" class="data row4 col8" >338.90</td>
#       <td id="T_b9f80_row4_col9" class="data row4 col9" >3.10</td>
#       <td id="T_b9f80_row4_col10" class="data row4 col10" >2.70</td>
#       <td id="T_b9f80_row4_col11" class="data row4 col11" >6790.24</td>
#       <td id="T_b9f80_row4_col12" class="data row4 col12" >-2371.50</td>
#     </tr>
#     <tr>
#       <th id="T_b9f80_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_b9f80_row5_col0" class="data row5 col0" >179.00</td>
#       <td id="T_b9f80_row5_col1" class="data row5 col1" >14.76</td>
#       <td id="T_b9f80_row5_col2" class="data row5 col2" >1.51</td>
#       <td id="T_b9f80_row5_col3" class="data row5 col3" >350.19</td>
#       <td id="T_b9f80_row5_col4" class="data row5 col4" >349.14</td>
#       <td id="T_b9f80_row5_col5" class="data row5 col5" >1.06</td>
#       <td id="T_b9f80_row5_col6" class="data row5 col6" >0.88</td>
#       <td id="T_b9f80_row5_col7" class="data row5 col7" >350.05</td>
#       <td id="T_b9f80_row5_col8" class="data row5 col8" >349.30</td>
#       <td id="T_b9f80_row5_col9" class="data row5 col9" >7.04</td>
#       <td id="T_b9f80_row5_col10" class="data row5 col10" >5.92</td>
#       <td id="T_b9f80_row5_col11" class="data row5 col11" >8010.63</td>
#       <td id="T_b9f80_row5_col12" class="data row5 col12" >-1074.00</td>
#     </tr>
#     <tr>
#       <th id="T_b9f80_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_b9f80_row6_col0" class="data row6 col0" >395.25</td>
#       <td id="T_b9f80_row6_col1" class="data row6 col1" >33.64</td>
#       <td id="T_b9f80_row6_col2" class="data row6 col2" >1.85</td>
#       <td id="T_b9f80_row6_col3" class="data row6 col3" >361.88</td>
#       <td id="T_b9f80_row6_col4" class="data row6 col4" >357.63</td>
#       <td id="T_b9f80_row6_col5" class="data row6 col5" >1.50</td>
#       <td id="T_b9f80_row6_col6" class="data row6 col6" >1.38</td>
#       <td id="T_b9f80_row6_col7" class="data row6 col7" >362.95</td>
#       <td id="T_b9f80_row6_col8" class="data row6 col8" >358.23</td>
#       <td id="T_b9f80_row6_col9" class="data row6 col9" >25.86</td>
#       <td id="T_b

# %%
# Plot Results

# Iteration 3 num2move 1
mean_median_error = results_iter3_1['Median_Error'].mean()
mean_median_cep = results_iter3_1['Median_CEP'].mean()
mean_median_x = results_iter3_1['Median_X'].mean()
mean_median_y = results_iter3_1['Median_Y'].mean()
radius = mean_median_cep
median_cep_legend = f'Median CEP Iter3_1 \nMean Error: {np.round(mean_median_error,1)}'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='blue', facecolor='none', linestyle='-', linewidth=2, label=median_cep_legend)
plt.gca().add_patch(circle_median)

# Iteration 3 num2move 2
mean_median_error = results_iter3_2['Median_Error'].mean()
mean_median_cep = results_iter3_2['Median_CEP'].mean()
mean_median_x = results_iter3_2['Median_X'].mean()
mean_median_y = results_iter3_2['Median_Y'].mean()
radius = mean_median_cep
median_cep_legend = f'Median CEP Iter3_2 \nMean Error: {np.round(mean_median_error,1)}'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='red', facecolor='none', linestyle='-', linewidth=2, label=median_cep_legend)
plt.gca().add_patch(circle_median)

plt.scatter(350,350,color='red', label='True Target Location', marker='x',s=200)


# Iteration 3 num2move 3
mean_median_error = results_iter3_3['Median_Error'].mean()
mean_median_cep = results_iter3_3['Median_CEP'].mean()
mean_median_x = results_iter3_3['Median_X'].mean()
mean_median_y = results_iter3_3['Median_Y'].mean()
radius = mean_median_cep
median_cep_legend = f'Median CEP Iter3_3 \nMean Error: {np.round(mean_median_error,1)}'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='black', facecolor='none', linestyle='-', linewidth=2, label=median_cep_legend)
plt.gca().add_patch(circle_median)

# Iteration 3 num2move 4
mean_median_error = results_iter3_4['Median_Error'].mean()
mean_median_cep = results_iter3_4['Median_CEP'].mean()
mean_median_x = results_iter3_4['Median_X'].mean()
mean_median_y = results_iter3_4['Median_Y'].mean()
radius = mean_median_cep
median_cep_legend = f'Median CEP Iter3_4 \nMean Error: {np.round(mean_median_error,1)}'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='green', facecolor='none', linestyle='-', linewidth=2, label=median_cep_legend)
plt.gca().add_patch(circle_median)

# Iteration 3 num2move 5
mean_median_error = results_iter3_5['Median_Error'].mean()
mean_median_cep = results_iter3_5['Median_CEP'].mean()
mean_median_x = results_iter3_5['Median_X'].mean()
mean_median_y = results_iter3_5['Median_Y'].mean()
radius = mean_median_cep
median_cep_legend = f'Median CEP Iter3_5 \nMean Error: {np.round(mean_median_error,1)}'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='orange', facecolor='none', linestyle='-', linewidth=2, label=median_cep_legend)
plt.gca().add_patch(circle_median)

# Iteration 3 num2move 6
mean_median_error = results_iter3_6['Median_Error'].mean()
mean_median_cep = results_iter3_6['Median_CEP'].mean()
mean_median_x = results_iter3_6['Median_X'].mean()
mean_median_y = results_iter3_6['Median_Y'].mean()
radius = mean_median_cep
median_cep_legend = f'Median CEP Iter3_6 \nMean Error: {np.round(mean_median_error,1)}'
circle_median = Ellipse((mean_median_x, mean_median_y), 2*radius, 2*radius, edgecolor='yellow', facecolor='none', linestyle='-', linewidth=2, label=median_cep_legend)
plt.gca().add_patch(circle_median)


plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(340, 360)
plt.ylim(340, 360)
plt.title('Median CEP for Iteration 3 based on Num2Move')
plt.legend(
    loc='lower center', 
    bbox_to_anchor=(0.5, -.35),
    ncol=3, 
)
plt.grid(True)
plt.axis('equal')  # Equal aspect ratio
plt.show()
